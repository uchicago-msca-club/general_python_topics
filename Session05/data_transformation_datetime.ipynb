# %% [markdown]
# ![Image](https://drive.google.com/uc?export=view&id=10B8NecPfn9sXRescmijQ8Zc2CO08fQm7)
#
# ## **Effective Date Column Handling in Pandas**
# ### ACC Tech Challenge Series, Winter 2020
# ### Terry Wang
#
# Source:
#
# https://towardsdatascience.com/simple-football-data-set-exploration-with-pandas-60a2bc56bd5a
#
# https://medium.com/datadriveninvestor/how-to-work-with-dates-in-pandas-like-a-pro-a84055a4819d
#
# https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
datafile = "./data/results.csv"
results = pd.read_csv(datafile)
results.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %% [markdown]
# ### **Converting date column to `datetime` data type**

# %%
results.dtypes
# Out:
# date          object
# home_team     object
# away_team     object
# home_score     int64
# away_score     int64
# tournament    object
# city          object
# country       object
# neutral         bool
# dtype: object

# %% [markdown]
# Convert `date` column to datetime dtype, using pandas function `to_datetime`.

# %%
results['date_time'] = pd.to_datetime(results.date)

# %%
results.dtypes
# Out:
# date                  object
# home_team             object
# away_team             object
# home_score             int64
# away_score             int64
# tournament            object
# city                  object
# country               object
# neutral                 bool
# date_time     datetime64[ns]
# dtype: object

# %% [markdown]
# When a column is `datetime` type, you can easily extract dates, resample, apply window functions, etc. directly using pandas.

# %% [markdown]
# Let's say I want to only use the year of the date in each observation, I can do the following:

# %%
# Access 

results.date_time.dt.year.head()
# Out:
# 0    1872
# 1    1873
# 2    1874
# 3    1875
# 4    1876
# Name: date_time, dtype: int64

# %%
# Count the number of observations for each year:

results.date_time.dt.year.value_counts().sort_index().head()
# Out:
# 1872    1
# 1873    1
# 1874    1
# 1875    1
# 1876    2
# Name: date_time, dtype: int64

# %% [markdown]
# And since pandas dataframes are integrated with matplotlib, you can directly plot the trendline:

# %%
results.date_time.dt.year.value_counts().sort_index().plot()

# %% [markdown]
# Since the output of the `.year` method is an array of the same length as the number of rows in the dataset, you can also use this as an indexing tool to filter rows.

# %%
results.date_time.dt.year[results.date_time.dt.year >= 2014].value_counts().sort_index().plot()

# %% [markdown]
# Use `.between` for easier indexing.

# %%
results.date_time.dt.year[results.date_time.dt.year.between(left=1990, 
                                                            right=2019)].value_counts().sort_index().plot()

# %% [markdown]
# Can use resample methods after making a datetime column the index, which opens up possibilities to apply window functions.

# %%
results_ymd = results.drop("date", axis=1).set_index("date_time")
results_ymd.head()
# Out:
#            home_team away_team  home_score  away_score tournament     city  \
# date_time
# 1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1873-03-08   England  Scotland           4           2   Friendly   London
# 1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 1875-03-06   England  Scotland           2           2   Friendly   London
# 1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#              country  neutral
# date_time
# 1872-11-30  Scotland    False
# 1873-03-08   England    False
# 1874-03-07  Scotland    False
# 1875-03-06   England    False
# 1876-03-04  Scotland    False

# %% [markdown]
# ### **`resample` method**

# %% [markdown]
# Resample is similar to group by in the sense that it will allow you to bin the rows using some rule, so that you can apply your operation on each bin. Below is an example of summing the numerical columns for each month.  Note that if there will be **ONE ROW FOR EACH MONTH BETWEEN THE MIN AND MAX MONTH IN THE DATASET, even if there are no observations corresponding to certain months**.  This can be useful or a nuisance depending on your use case, but for most time series problems, this can be a good way to fill missing data, as the structure of the data requires that each observation is from time intervals of equal lengths.

# %%
# Use results.resample("M", on="date_time") if date_time is a column and not the index

results_ymd.resample("M").sum().head(10)
# Out:
#             home_score  away_score  neutral
# date_time
# 1872-11-30           0           0      0.0
# 1872-12-31           0           0      0.0
# 1873-01-31           0           0      0.0
# 1873-02-28           0           0      0.0
# 1873-03-31           4           2      0.0
# 1873-04-30           0           0      0.0
# 1873-05-31           0           0      0.0
# 1873-06-30           0           0      0.0
# 1873-07-31           0           0      0.0
# 1873-08-31           0           0      0.0

# %% [markdown]
# ### **`rolling` method**

# %% [markdown]
# `rolling` method allows you to apply window functions to a time series data.  You can use time intervals directly as an argument to the method:

# %%
# To get total number of goals for each 90 day period in the dataset:

results_ymd.resample("M").sum().resample("90d").sum().head()
# Out:
#             home_score  away_score  neutral
# date_time
# 1872-11-30           0           0      0.0
# 1873-02-28           4           2      0.0
# 1873-05-29           0           0      0.0
# 1873-08-27           0           0      0.0
# 1873-11-25           0           0      0.0

# %% [markdown]
# Note that since our datetime index is in terms of days (that's the smallest unit here), we would have to make the rolling window in terms of days as well, or pandas will return an exception.  If you want the window to be measured in terms of months, simply convert that length in terms of days.
#
# The function you choose to apply to the window is arbitrary as well using `.apply()` at the end, as long as it is able to take an array of numbers and reduce it to one number (for example, the `.mean()` function is basically taking an array of numbers in a column within the window and outputting the mean of it).

# %% [markdown]
# ### **Frequency**

# %% [markdown]
# When the data points of a time series are uniformly spaced in time (e.g., hourly, daily, monthly, etc.), the time series can be associated with a frequency in pandas. This is an alternative way to make the time interval between rows uniform and even quickly interpolate any missing data.

# %%
results_first5 = results_ymd.head()
results_first5
# Out:
#            home_team away_team  home_score  away_score tournament     city  \
# date_time
# 1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1873-03-08   England  Scotland           4           2   Friendly   London
# 1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 1875-03-06   England  Scotland           2           2   Friendly   London
# 1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#              country  neutral
# date_time
# 1872-11-30  Scotland    False
# 1873-03-08   England    False
# 1874-03-07  Scotland    False
# 1875-03-06   England    False
# 1876-03-04  Scotland    False

# %%
# assign monthly frequency to the date_time column to make each row a month from 1872-11-30 to 1876-03-04
# each row now represents a month with any missing data filled with data from the last valid observation before the index date
results_first5.asfreq("M", method='pad')
# Out:
#            home_team away_team  home_score  away_score tournament     city  \
# date_time
# 1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1872-12-31  Scotland   England           0           0   Friendly  Glasgow
# 1873-01-31  Scotland   England           0           0   Friendly  Glasgow
# 1873-02-28  Scotland   England           0           0   Friendly  Glasgow
# 1873-03-31   England  Scotland           4           2   Friendly   London
# 1873-04-30   England  Scotland           4           2   Friendly   London
# 1873-05-31   England  Scotland           4           2   Friendly   London
# 1873-06-30   England  Scotland           4           2   Friendly   London
# 1873-07-31   England  Scotland           4           2   Friendly   London
# 1873-08-31   England  Scotland           4           2   Friendly   London
# 1873-09-30   England  Scotland           4           2   Friendly   London
# 1873-10-31   England  Scotland           4           2   Friendly   London
# 1873-11-30   England  Scotland           4           2   Friendly   London
# 1873-12-31   England  Scotland           4           2   Friendly   London
# 1874-01-31   England  Scotland           4           2   Friendly   London
# 1874-02-28   England  Scotland           4           2   Friendly   London
# 1874-03-31  Scotland   England           2           1   Friendly  Glasgow
# 1874-04-30  Scotland   England           2           1   Friendly  Glasgow
# 1874-05-31  Scotland   England           2           1   Friendly  Glasgow
# 1874-06-30  Scotland   England           2           1   Friendly  Glasgow
# 1874-07-31  Scotland   England           2           1   Friendly  Glasgow
# 1874-08-31  Scotland   England           2           1   Friendly  Glasgow
# 1874-09-30  Scotland   England           2           1   Friendly  Glasgow
# 1874-10-31  Scotland   England           2           1   Friendly  Glasgow
# 1874-11-30  Scotland   England           2           1   Friendly  Glasgow
# 1874-12-31  Scotland   England           2           1   Friendly  Glasgow
# 1875-01-31  Scotland   England           2           1   Friendly  Glasgow
# 1875-02-28  Scotland   England           2           1   Friendly  Glasgow
# 1875-03-31   England  Scotland           2           2   Friendly   London
# 1875-04-30   England  Scotland           2           2   Friendly   London
# 1875-05-31   England  Scotland           2           2   Friendly   London
# 1875-06-30   England  Scotland           2           2   Friendly   London
# 1875-07-31   England  Scotland           2           2   Friendly   London
# 1875-08-31   England  Scotland           2           2   Friendly   London
# 1875-09-30   England  Scotland           2           2   Friendly   London
# 1875-10-31   England  Scotland           2           2   Friendly   London
# 1875-11-30   England  Scotland           2           2   Friendly   London
# 1875-12-31   England  Scotland           2           2   Friendly   London
# 1876-01-31   England  Scotland           2           2   Friendly   London
# 1876-02-29   England  Scotland           2           2   Friendly   London
#
#              country  neutral
# date_time
# 1872-11-30  Scotland    False
# 1872-12-31  Scotland    False
# 1873-01-31  Scotland    False
# 1873-02-28  Scotland    False
# 1873-03-31   England    False
# 1873-04-30   England    False
# 1873-05-31   England    False
# 1873-06-30   England    False
# 1873-07-31   England    False
# 1873-08-31   England    False
# 1873-09-30   England    False
# 1873-10-31   England    False
# 1873-11-30   England    False
# 1873-12-31   England    False
# 1874-01-31   England    False
# 1874-02-28   England    False
# 1874-03-31  Scotland    False
# 1874-04-30  Scotland    False
# 1874-05-31  Scotland    False
# 1874-06-30  Scotland    False
# 1874-07-31  Scotland    False
# 1874-08-31  Scotland    False
# 1874-09-30  Scotland    False
# 1874-10-31  Scotland    False
# 1874-11-30  Scotland    False
# 1874-12-31  Scotland    False
# 1875-01-31  Scotland    False
# 1875-02-28  Scotland    False
# 1875-03-31   England    False
# 1875-04-30   England    False
# 1875-05-31   England    False
# 1875-06-30   England    False
# 1875-07-31   England    False
# 1875-08-31   England    False
# 1875-09-30   England    False
# 1875-10-31   England    False
# 1875-11-30   England    False
# 1875-12-31   England    False
# 1876-01-31   England    False
# 1876-02-29   England    False
