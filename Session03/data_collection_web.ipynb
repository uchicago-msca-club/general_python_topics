# %% [markdown]
# ![Image](https://drive.google.com/uc?export=view&id=10B8NecPfn9sXRescmijQ8Zc2CO08fQm7)
#
# ## **Data Collection via Web Scraping & API**
# ### ACC Tech Challenge Series, Sping 2020
# ### Harper Xiang

# %% [markdown]
# # Json API

# %% [markdown]
# “JSON (JavaScript Object Notation) is a lightweight data-interchange format. … JSON is a text format that is completely language independent but uses conventions that are familiar to programmers of the C-family of languages, including C, C++, C#, Java, JavaScript, Perl, Python, and many others. These properties make JSON an ideal data-interchange language.
#
# JSON is built on two structures:
# A collection of name/value pairs. In various languages, this is realized as an object, record, struct, dictionary, hash table, keyed list, or associative array.
# An ordered list of values. In most languages, this is realized as an array, vector, list, or sequence.”
#
# (https://www.json.org)

# %%
import requests
import json

# %%
# Find a URL
# https://github.com/r-spacex/SpaceX-API
url = "https://api.spacexdata.com/v2/launchpads"

# %%
# Getting the data from the URL server to local
response = requests.get(url)

# %%
# using JSON structure to store the data gotten
data = response.json()
print(json.dumps(data, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "attempted_launches": 0,
#         "details": "SpaceX original west coast launch pad for Falcon 1. Performed a static fire but was never used for a launch and abandoned due to scheduling conflicts.",
#         "full_name": "Vandenberg Air Force Base Space Launch Complex 3W",
#         "id": "vafb_slc_3w",
#         "location": {
#             "latitude": 34.6440904,
#             "longitude": -120.5931438,
#             "name": "Vandenberg Air Force Base",
#             "region": "California"
#         },
#         "name": "VAFB SLC 3W",
#         "padid": 5,
#         "status": "retired",
#         "successful_launches": 0,
#         "vehicles_launched": [
#             "Falcon 1"
#         ],
#         "wikipedia": "https://en.wikipedia.org/wiki/Vandenberg_AFB_Space_Launch_Complex_3"
#     },
#     {
#         "attempted_launches": 52,
#         "details": "SpaceX primary Falcon 9 launch pad, where all east coast Falcon 9s launched prior to the AMOS-6 anomaly. Initially used to launch Titan rockets for Lockheed Martin. Back online since CRS-13 on 2017-12-15.",
#         "full_name": "Cape Canaveral Air Force Station Space Launch Complex 40",
#         "id": "ccafs_slc_40",
#         "location": {
#             "latitude": 28.5618571,
#             "longitude": -80.577366,
#             "name": "Cape Canaveral",
#             "region": "Florida"
#         },
#         "name": "CCAFS SLC 40",
#         "padid": 2,
#         "status": "active",
#         "successful_launches": 50,
#         "vehicles_launched": [
#             "Falcon 9"
#         ],
#         "wikipedia": "https://en.wikipedia.org/wiki/Cape_Canaveral_Air_Force_Station_Space_Launch_Complex_40"
#     },
#     {
#         "attempted_launches": 0,
#         "details": "SpaceX new launch site currently under construction to help keep up with the Falcon 9 and Heavy manifests. Expected to be completed in late 2018. Initially will be limited to 12 flights per year, and only GTO launches.",
#         "full_name": "SpaceX South Texas Launch Site",
#         "id": "stls",
#         "location": {
#             "latitude": 25.9972641,
#             "longitude": -97.1560845,
#             "name": "Boca Chica Village",
#             "region": "Texas"
#         },
#         "name": "STLS",
#         "padid": 8,
#         "status": "under construction",
#         "successful_launches": 0,
#         "vehicles_launched": [
#             "Falcon 9"
#         ],
#         "wikipedia": "https://en.wikipedia.org/wiki/SpaceX_South_Texas_Launch_Site"
#     },
#     {
#         "attempted_launches": 5,
#         "details": "SpaceX original launch site, where all of the Falcon 1 launches occured. Abandoned as SpaceX decided against upgrading the pad to support Falcon 9.",
#         "full_name": "Kwajalein Atoll Omelek Island",
#         "id": "kwajalein_atoll",
#         "location": {
#             "latitude": 9.0477206,
#             "longitude": 167.7431292,
#             "name": "Omelek Island",
#             "region": "Marshall Islands"
#         },
#         "name": "Kwajalein Atoll",
#         "padid": 1,
#         "status": "retired",
#         "successful_launches": 2,
#         "vehicles_launched": [
#             "Falcon 1"
#         ],
#         "wikipedia": "https://en.wikipedia.org/wiki/Omelek_Island"
#     },
#     {
#         "attempted_launches": 15,
#         "details": "SpaceX primary west coast launch pad for polar orbits and sun synchronous orbits, primarily used for Iridium. Also intended to be capable of launching Falcon Heavy.",
#         "full_name": "Vandenberg Air Force Base Space Launch Complex 4E",
#         "id": "vafb_slc_4e",
#         "location": {
#             "latitude": 34.632093,
#             "longitude": -120.610829,
#             "name": "Vandenberg Air Force Base",
#             "region": "California"
#         },
#         "name": "VAFB SLC 4E",
#         "padid": 6,
#         "status": "active",
#         "successful_launches": 15,
#         "vehicles_launched": [
#             "Falcon 9"
#         ],
#         "wikipedia": "https://en.wikipedia.org/wiki/Vandenberg_AFB_Space_Launch_Complex_4"
#     },
#     {
#         "attempted_launches": 21,
#         "details": "NASA historic launch pad that launched most of the Saturn V and Space Shuttle missions. Initially for Falcon Heavy launches, it is now launching all of SpaceX east coast missions due to the damage from the AMOS-6 anomaly. After SLC-40 repairs are complete, it will be upgraded to support Falcon Heavy, a process which will take about two months. In the future it will launch commercial crew missions and the Interplanetary Transport System.",
#         "full_name": "Kennedy Space Center Historic Launch Complex 39A",
#         "id": "ksc_lc_39a",
#         "location": {
#             "latitude": 28.6080585,
#             "longitude": -80.6039558,
#             "name": "Cape Canaveral",
#             "region": "Florida"
#         },
#         "name": "KSC LC 39A",
#         "padid": 4,
#         "status": "active",
#         "successful_launches": 21,
#         "vehicles_launched": [
#             "Falcon 9",
#             "Falcon Heavy"
#         ],
#         "wikipedia": "https://en.wikipedia.org/wiki/Kennedy_Space_Center_Launch_Complex_39#Launch_Complex_39A"
#     }
# ]

# %%
# Getting the value of a Field (“Key”)
data[0]['name']
# Out:
# 'VAFB SLC 3W'

# %% [markdown]
# # Social Media Mining

# %% [markdown]
# Applying for Twitter API:
#
# https://developer.twitter.com/en/docs
#
# Tweepy Guideline:
#
# https://tweepy.readthedocs.io/en/v3.5.0/
#
# http://docs.tweepy.org/en/v3.6.0/api.html
#
# Install Twitter library/wraps
#
# $$ pip install tweepy

# %%
import tweepy

# %%
# Import Twitter API Keys
from config import consumer_key, consumer_secret, access_token, access_token_secret

# %%
# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %% [markdown]
# ### Get Tweets from the User(whose API_key)’s home page

# %%
# Including the User’s own and his following’s tweets
public_tweets = api.home_timeline()
public_tweets
# Out:
# [{'created_at': 'Thu Apr 30 02:45:15 +0000 2020',
#   'id': 1255689644244680709,
#   'id_str': '1255689644244680709',
#   'text': 'The people who brought you "Orange Is The New Black" are working on "Social Distance," an anthology series for Netf… https://t.co/cyYeBOf9AK',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/cyYeBOf9AK',
#      'expanded_url': 'https://twitter.com/i/web/status/1255689644244680709',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 759251,
#    'id_str': '759251',
#    'name': 'CNN',
#    'screen_name': 'CNN',
#    'location': '',
#    'description': 'It’s our job to #GoThere & tell the most difficult stories. Join us! For more breaking news updates follow @CNNBRK  & Download our app https://t.co/UCHG9M367J',
#    'url': 'http://t.co/IaghNW8Xm2',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/IaghNW8Xm2',
#        'expanded_url': 'http://www.cnn.com',
#        'display_url': 'cnn.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': [{'url': 'https://t.co/UCHG9M367J',
#        'expanded_url': 'http://cnn.com/apps',
#        'display_url': 'cnn.com/apps',
#        'indices': [135, 158]}]}},
#    'protected': False,
#    'followers_count': 47733545,
#    'friends_count': 1106,
#    'listed_count': 145866,
#    'created_at': 'Fri Feb 09 00:35:02 +0000 2007',
#    'favourites_count': 1429,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 298104,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '323232',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/508960761826131968/LnvhR8ED_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/508960761826131968/LnvhR8ED_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/759251/1564637377',
#    'profile_link_color': '004287',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'EEEEEE',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 10,
#   'favorite_count': 42,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Apr 30 02:45:00 +0000 2020',
#   'id': 1255689580436750340,
#   'id_str': '1255689580436750340',
#   'text': 'Stop the music: 2020 Newport folk, jazz festivals canceled https://t.co/dKxIG7nCM4 #7News',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': '7News', 'indices': [83, 89]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/dKxIG7nCM4',
#      'expanded_url': 'http://whdh.com/news/stop-the-music-2020-newport-folk-jazz-festivals-canceled/',
#      'display_url': 'whdh.com/news/stop-the-…',
#      'indices': [59, 82]}]},
#   'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 16558796,
#    'id_str': '16558796',
#    'name': '7News Boston WHDH',
#    'screen_name': '7News',
#    'location': 'Boston',
#    'description': 'New England and Boston News, #BreakingNews. Have a tip? Tweet us with the hashtag #7News .\n\nFacebook: 7News - WHDH Boston\nInstagram: 7news',
#    'url': 'https://t.co/5kYmGIlLqH',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/5kYmGIlLqH',
#        'expanded_url': 'http://www.whdh.com',
#        'display_url': 'whdh.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 333209,
#    'friends_count': 1127,
#    'listed_count': 2787,
#    'created_at': 'Thu Oct 02 13:11:54 +0000 2008',
#    'favourites_count': 4454,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 284216,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/727880916354355200/-n81FrYu_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/727880916354355200/-n81FrYu_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16558796/1543525290',
#    'profile_link_color': '1B54D6',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'F0F0F0',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 1,
#   'favorite_count': 1,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Apr 30 02:44:55 +0000 2020',
#   'id': 1255689561511997445,
#   'id_str': '1255689561511997445',
#   'text': 'Costco will require shoppers to wear a face mask starting next week https://t.co/NJWEuknbrW https://t.co/oT3jqQxcMK',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/NJWEuknbrW',
#      'expanded_url': 'https://cbsn.ws/2WaPB7N',
#      'display_url': 'cbsn.ws/2WaPB7N',
#      'indices': [68, 91]}],
#    'media': [{'id': 1255689559867830272,
#      'id_str': '1255689559867830272',
#      'indices': [92, 115],
#      'media_url': 'http://pbs.twimg.com/media/EW0bAHQWsAA3Eoz.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/EW0bAHQWsAA3Eoz.jpg',
#      'url': 'https://t.co/oT3jqQxcMK',
#      'display_url': 'pic.twitter.com/oT3jqQxcMK',
#      'expanded_url': 'https://twitter.com/CBSNews/status/1255689561511997445/photo/1',
#      'type': 'photo',
#      'sizes': {'medium': {'w': 1024, 'h': 538, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 1024, 'h': 538, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 357, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 1255689559867830272,
#      'id_str': '1255689559867830272',
#      'indices': [92, 115],
#      'media_url': 'http://pbs.twimg.com/media/EW0bAHQWsAA3Eoz.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/EW0bAHQWsAA3Eoz.jpg',
#      'url': 'https://t.co/oT3jqQxcMK',
#      'display_url': 'pic.twitter.com/oT3jqQxcMK',
#      'expanded_url': 'https://twitter.com/CBSNews/status/1255689561511997445/photo/1',
#      'type': 'photo',
#      'sizes': {'medium': {'w': 1024, 'h': 538, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 1024, 'h': 538, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 357, 'resize': 'fit'}}}]},
#   'source': '<a href="https://www.sprinklr.com" rel="nofollow">Sprinklr</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 15012486,
#    'id_str': '15012486',
#    'name': 'CBS News',
#    'screen_name': 'CBSNews',
#    'location': 'New York, NY',
#    'description': 'Your source for original reporting and trusted news.',
#    'url': 'https://t.co/VGut7r2Vg5',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/VGut7r2Vg5',
#        'expanded_url': 'http://CBSNews.com',
#        'display_url': 'CBSNews.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 7541383,
#    'friends_count': 515,
#    'listed_count': 52659,
#    'created_at': 'Thu Jun 05 00:54:31 +0000 2008',
#    'favourites_count': 299,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 252421,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': 'D9DADA',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/645966750941626368/d0Q4voGK_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/645966750941626368/d0Q4voGK_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15012486/1581519449',
#    'profile_link_color': 'B12124',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EAEDF0',
#    'profile_text_color': '000000',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 18,
#   'favorite_count': 56,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Apr 30 02:42:00 +0000 2020',
#   'id': 1255688825486991360,
#   'id_str': '1255688825486991360',
#   'text': 'The New York City subway system is “a huge problem” when it comes to coronavirus spread in the Big Apple, says Dr.… https://t.co/laQCnNJTXF',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/laQCnNJTXF',
#      'expanded_url': 'https://twitter.com/i/web/status/1255688825486991360',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [116, 139]}]},
#   'source': '<a href="https://studio.twitter.com" rel="nofollow">Twitter Media Studio</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 759251,
#    'id_str': '759251',
#    'name': 'CNN',
#    'screen_name': 'CNN',
#    'location': '',
#    'description': 'It’s our job to #GoThere & tell the most difficult stories. Join us! For more breaking news updates follow @CNNBRK  & Download our app https://t.co/UCHG9M367J',
#    'url': 'http://t.co/IaghNW8Xm2',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/IaghNW8Xm2',
#        'expanded_url': 'http://www.cnn.com',
#        'display_url': 'cnn.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': [{'url': 'https://t.co/UCHG9M367J',
#        'expanded_url': 'http://cnn.com/apps',
#        'display_url': 'cnn.com/apps',
#        'indices': [135, 158]}]}},
#    'protected': False,
#    'followers_count': 47733545,
#    'friends_count': 1106,
#    'listed_count': 145866,
#    'created_at': 'Fri Feb 09 00:35:02 +0000 2007',
#    'favourites_count': 1429,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 298104,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '323232',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/508960761826131968/LnvhR8ED_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/508960761826131968/LnvhR8ED_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/759251/1564637377',
#    'profile_link_color': '004287',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'EEEEEE',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 34,
#   'favorite_count': 89,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Apr 30 02:40:05 +0000 2020',
#   'id': 1255688344014671872,
#   'id_str': '1255688344014671872',
#   'text': 'Dr. Fauci cautioned that modest results from a trial of the experimental drug remdesivir still needed to be properl… https://t.co/jMimgtAiXy',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/jMimgtAiXy',
#      'expanded_url': 'https://twitter.com/i/web/status/1255688344014671872',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 807095,
#    'id_str': '807095',
#    'name': 'The New York Times',
#    'screen_name': 'nytimes',
#    'location': 'New York City',
#    'description': 'News tips? Share them here: https://t.co/ghL9OoYKMM',
#    'url': 'http://t.co/ahvuWqicF9',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/ahvuWqicF9',
#        'expanded_url': 'http://www.nytimes.com/',
#        'display_url': 'nytimes.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': [{'url': 'https://t.co/ghL9OoYKMM',
#        'expanded_url': 'http://nyti.ms/2FVHq9v',
#        'display_url': 'nyti.ms/2FVHq9v',
#        'indices': [28, 51]}]}},
#    'protected': False,
#    'followers_count': 46430534,
#    'friends_count': 904,
#    'listed_count': 206852,
#    'created_at': 'Fri Mar 02 20:41:42 +0000 2007',
#    'favourites_count': 18483,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 394244,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1098244578472280064/gjkVMelR_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1098244578472280064/gjkVMelR_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/807095/1584666392',
#    'profile_link_color': '607696',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 61,
#   'favorite_count': 134,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Apr 30 02:35:06 +0000 2020',
#   'id': 1255687088252563456,
#   'id_str': '1255687088252563456',
#   'text': 'On Monday, President Trump instructed states to "maximize the use of all available testing platforms and venues" as… https://t.co/diS76Zbqo4',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/diS76Zbqo4',
#      'expanded_url': 'https://twitter.com/i/web/status/1255687088252563456',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 759251,
#    'id_str': '759251',
#    'name': 'CNN',
#    'screen_name': 'CNN',
#    'location': '',
#    'description': 'It’s our job to #GoThere & tell the most difficult stories. Join us! For more breaking news updates follow @CNNBRK  & Download our app https://t.co/UCHG9M367J',
#    'url': 'http://t.co/IaghNW8Xm2',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/IaghNW8Xm2',
#        'expanded_url': 'http://www.cnn.com',
#        'display_url': 'cnn.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': [{'url': 'https://t.co/UCHG9M367J',
#        'expanded_url': 'http://cnn.com/apps',
#        'display_url': 'cnn.com/apps',
#        'indices': [135, 158]}]}},
#    'protected': False,
#    'followers_count': 47733545,
#    'friends_count': 1106,
#    'listed_count': 145866,
#    'created_at': 'Fri Feb 09 00:35:02 +0000 2007',
#    'favourites_count': 1429,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 298104,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '323232',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/508960761826131968/LnvhR8ED_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/508960761826131968/LnvhR8ED_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/759251/1564637377',
#    'profile_link_color': '004287',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'EEEEEE',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 46,
#   'favorite_count': 129,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Apr 30 02:35:00 +0000 2020',
#   'id': 1255687063875141632,
#   'id_str': '1255687063875141632',
#   'text': 'Dr. Andre Kalil, a key clinical trial researcher on remdesivir, says preliminary results “were so important ... we… https://t.co/CdLuzxH6mn',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/CdLuzxH6mn',
#      'expanded_url': 'https://twitter.com/i/web/status/1255687063875141632',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [116, 139]}]},
#   'source': '<a href="https://studio.twitter.com" rel="nofollow">Twitter Media Studio</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 759251,
#    'id_str': '759251',
#    'name': 'CNN',
#    'screen_name': 'CNN',
#    'location': '',
#    'description': 'It’s our job to #GoThere & tell the most difficult stories. Join us! For more breaking news updates follow @CNNBRK  & Download our app https://t.co/UCHG9M367J',
#    'url': 'http://t.co/IaghNW8Xm2',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/IaghNW8Xm2',
#        'expanded_url': 'http://www.cnn.com',
#        'display_url': 'cnn.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': [{'url': 'https://t.co/UCHG9M367J',
#        'expanded_url': 'http://cnn.com/apps',
#        'display_url': 'cnn.com/apps',
#        'indices': [135, 158]}]}},
#    'protected': False,
#    'followers_count': 47733545,
#    'friends_count': 1106,
#    'listed_count': 145866,
#    'created_at': 'Fri Feb 09 00:35:02 +0000 2007',
#    'favourites_count': 1429,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 298104,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '323232',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/508960761826131968/LnvhR8ED_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/508960761826131968/LnvhR8ED_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/759251/1564637377',
#    'profile_link_color': '004287',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'EEEEEE',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 42,
#   'favorite_count': 113,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Apr 30 02:34:06 +0000 2020',
#   'id': 1255686838444064772,
#   'id_str': '1255686838444064772',
#   'text': "A federal appeals court has affirmed a lower court's decision that a Kansas voting law, crafted by conservative har… https://t.co/CrPxnv6NKl",
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/CrPxnv6NKl',
#      'expanded_url': 'https://twitter.com/i/web/status/1255686838444064772',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 759251,
#    'id_str': '759251',
#    'name': 'CNN',
#    'screen_name': 'CNN',
#    'location': '',
#    'description': 'It’s our job to #GoThere & tell the most difficult stories. Join us! For more breaking news updates follow @CNNBRK  & Download our app https://t.co/UCHG9M367J',
#    'url': 'http://t.co/IaghNW8Xm2',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/IaghNW8Xm2',
#        'expanded_url': 'http://www.cnn.com',
#        'display_url': 'cnn.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': [{'url': 'https://t.co/UCHG9M367J',
#        'expanded_url': 'http://cnn.com/apps',
#        'display_url': 'cnn.com/apps',
#        'indices': [135, 158]}]}},
#    'protected': False,
#    'followers_count': 47733545,
#    'friends_count': 1106,
#    'listed_count': 145866,
#    'created_at': 'Fri Feb 09 00:35:02 +0000 2007',
#    'favourites_count': 1429,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 298104,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '323232',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/508960761826131968/LnvhR8ED_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/508960761826131968/LnvhR8ED_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/759251/1564637377',
#    'profile_link_color': '004287',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'EEEEEE',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 73,
#   'favorite_count': 256,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Apr 30 02:31:06 +0000 2020',
#   'id': 1255686083888758784,
#   'id_str': '1255686083888758784',
#   'text': "The US ambassador to Russia and the family of Paul Whelan have expressed concern for Whelan's treatment and well-be… https://t.co/inQA9mL2RG",
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/inQA9mL2RG',
#      'expanded_url': 'https://twitter.com/i/web/status/1255686083888758784',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 759251,
#    'id_str': '759251',
#    'name': 'CNN',
#    'screen_name': 'CNN',
#    'location': '',
#    'description': 'It’s our job to #GoThere & tell the most difficult stories. Join us! For more breaking news updates follow @CNNBRK  & Download our app https://t.co/UCHG9M367J',
#    'url': 'http://t.co/IaghNW8Xm2',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/IaghNW8Xm2',
#        'expanded_url': 'http://www.cnn.com',
#        'display_url': 'cnn.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': [{'url': 'https://t.co/UCHG9M367J',
#        'expanded_url': 'http://cnn.com/apps',
#        'display_url': 'cnn.com/apps',
#        'indices': [135, 158]}]}},
#    'protected': False,
#    'followers_count': 47733545,
#    'friends_count': 1106,
#    'listed_count': 145866,
#    'created_at': 'Fri Feb 09 00:35:02 +0000 2007',
#    'favourites_count': 1429,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 298104,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '323232',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/508960761826131968/LnvhR8ED_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/508960761826131968/LnvhR8ED_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/759251/1564637377',
#    'profile_link_color': '004287',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'EEEEEE',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 25,
#   'favorite_count': 58,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Apr 30 02:30:00 +0000 2020',
#   'id': 1255685805902688256,
#   'id_str': '1255685805902688256',
#   'text': 'Somerville detective fighting for his life after contracting COVID-19 showing signs of progress https://t.co/CZfe0zG2Ac #7News',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': '7News', 'indices': [120, 126]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/CZfe0zG2Ac',
#      'expanded_url': 'http://whdh.com/news/somerville-detective-fighting-for-his-life-after-contracting-covid-19-showing-signs-of-progress/',
#      'display_url': 'whdh.com/news/somervill…',
#      'indices': [96, 119]}]},
#   'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 16558796,
#    'id_str': '16558796',
#    'name': '7News Boston WHDH',
#    'screen_name': '7News',
#    'location': 'Boston',
#    'description': 'New England and Boston News, #BreakingNews. Have a tip? Tweet us with the hashtag #7News .\n\nFacebook: 7News - WHDH Boston\nInstagram: 7news',
#    'url': 'https://t.co/5kYmGIlLqH',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/5kYmGIlLqH',
#        'expanded_url': 'http://www.whdh.com',
#        'display_url': 'whdh.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 333209,
#    'friends_count': 1127,
#    'listed_count': 2787,
#    'created_at': 'Thu Oct 02 13:11:54 +0000 2008',
#    'favourites_count': 4454,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 284216,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/727880916354355200/-n81FrYu_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/727880916354355200/-n81FrYu_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16558796/1543525290',
#    'profile_link_color': '1B54D6',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'F0F0F0',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 4,
#   'favorite_count': 11,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Apr 30 02:29:36 +0000 2020',
#   'id': 1255685705310908416,
#   'id_str': '1255685705310908416',
#   'text': 'Deserted places in America, Italy, China and more amid the coronavirus pandemic https://t.co/QyzBTNIOaL https://t.co/Ry3oo4waZr',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/QyzBTNIOaL',
#      'expanded_url': 'https://cbsn.ws/2Yi5v2J',
#      'display_url': 'cbsn.ws/2Yi5v2J',
#      'indices': [80, 103]}],
#    'media': [{'id': 1255685703775793154,
#      'id_str': '1255685703775793154',
#      'indices': [104, 127],
#      'media_url': 'http://pbs.twimg.com/media/EW0XfqMXsAIDPtw.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/EW0XfqMXsAIDPtw.jpg',
#      'url': 'https://t.co/Ry3oo4waZr',
#      'display_url': 'pic.twitter.com/Ry3oo4waZr',
#      'expanded_url': 'https://twitter.com/CBSNews/status/1255685705310908416/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 1024, 'h': 538, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 357, 'resize': 'fit'},
#       'large': {'w': 1024, 'h': 538, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 1255685703775793154,
#      'id_str': '1255685703775793154',
#      'indices': [104, 127],
#      'media_url': 'http://pbs.twimg.com/media/EW0XfqMXsAIDPtw.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/EW0XfqMXsAIDPtw.jpg',
#      'url': 'https://t.co/Ry3oo4waZr',
#      'display_url': 'pic.twitter.com/Ry3oo4waZr',
#      'expanded_url': 'https://twitter.com/CBSNews/status/1255685705310908416/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 1024, 'h': 538, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 357, 'resize': 'fit'},
#       'large': {'w': 1024, 'h': 538, 'resize': 'fit'}}}]},
#   'source': '<a href="https://www.sprinklr.com" rel="nofollow">Sprinklr</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 15012486,
#    'id_str': '15012486',
#    'name': 'CBS News',
#    'screen_name': 'CBSNews',
#    'location': 'New York, NY',
#    'description': 'Your source for original reporting and trusted news.',
#    'url': 'https://t.co/VGut7r2Vg5',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/VGut7r2Vg5',
#        'expanded_url': 'http://CBSNews.com',
#        'display_url': 'CBSNews.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 7541383,
#    'friends_count': 515,
#    'listed_count': 52659,
#    'created_at': 'Thu Jun 05 00:54:31 +0000 2008',
#    'favourites_count': 299,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 252421,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': 'D9DADA',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/645966750941626368/d0Q4voGK_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/645966750941626368/d0Q4voGK_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15012486/1581519449',
#    'profile_link_color': 'B12124',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EAEDF0',
#    'profile_text_color': '000000',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 7,
#   'favorite_count': 18,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Apr 30 02:26:00 +0000 2020',
#   'id': 1255684798833586181,
#   'id_str': '1255684798833586181',
#   'text': 'Former Goldman Sachs President and CEO Gary Cohn says weeks of stay-at-home orders may have drastically altered con… https://t.co/80M0YTrAv0',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/80M0YTrAv0',
#      'expanded_url': 'https://twitter.com/i/web/status/1255684798833586181',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="https://studio.twitter.com" rel="nofollow">Twitter Media Studio</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 759251,
#    'id_str': '759251',
#    'name': 'CNN',
#    'screen_name': 'CNN',
#    'location': '',
#    'description': 'It’s our job to #GoThere & tell the most difficult stories. Join us! For more breaking news updates follow @CNNBRK  & Download our app https://t.co/UCHG9M367J',
#    'url': 'http://t.co/IaghNW8Xm2',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/IaghNW8Xm2',
#        'expanded_url': 'http://www.cnn.com',
#        'display_url': 'cnn.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': [{'url': 'https://t.co/UCHG9M367J',
#        'expanded_url': 'http://cnn.com/apps',
#        'display_url': 'cnn.com/apps',
#        'indices': [135, 158]}]}},
#    'protected': False,
#    'followers_count': 47733545,
#    'friends_count': 1106,
#    'listed_count': 145866,
#    'created_at': 'Fri Feb 09 00:35:02 +0000 2007',
#    'favourites_count': 1429,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 298104,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '323232',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/508960761826131968/LnvhR8ED_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/508960761826131968/LnvhR8ED_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/759251/1564637377',
#    'profile_link_color': '004287',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'EEEEEE',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 36,
#   'favorite_count': 146,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Apr 30 02:22:51 +0000 2020',
#   'id': 1255684008782057472,
#   'id_str': '1255684008782057472',
#   'text': 'https://t.co/RJwWLN4JHL',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/RJwWLN4JHL',
#      'expanded_url': 'https://www.foxnews.com/sports/yankees-giancarlo-stanton-donating-face-shields-coronavirus',
#      'display_url': 'foxnews.com/sports/yankees…',
#      'indices': [0, 23]}]},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1367531,
#    'id_str': '1367531',
#    'name': 'Fox News',
#    'screen_name': 'FoxNews',
#    'location': 'U.S.A.',
#    'description': "Follow America's #1 cable news network, delivering you breaking news, insightful analysis, and must-see videos. https://t.co/3gb0b8MMza",
#    'url': 'http://t.co/ZYG58XZtAC',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/ZYG58XZtAC',
#        'expanded_url': 'http://www.foxnews.com',
#        'display_url': 'foxnews.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': [{'url': 'https://t.co/3gb0b8MMza',
#        'expanded_url': 'http://foxnews.com/contact',
#        'display_url': 'foxnews.com/contact',
#        'indices': [112, 135]}]}},
#    'protected': False,
#    'followers_count': 19054183,
#    'friends_count': 269,
#    'listed_count': 67443,
#    'created_at': 'Sat Mar 17 19:01:26 +0000 2007',
#    'favourites_count': 0,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 418418,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '0E2331',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/918480715158716419/4X8oCbge_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/918480715158716419/4X8oCbge_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1367531/1492649996',
#    'profile_link_color': '183A52',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'F4F4F4',
#    'profile_text_color': '000000',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 34,
#   'favorite_count': 186,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'und'},
#  {'created_at': 'Thu Apr 30 02:22:00 +0000 2020',
#   'id': 1255683792427245570,
#   'id_str': '1255683792427245570',
#   'text': 'A coronavirus patient who was treated with remdesivir says he felt better within two days of taking the drug and he… https://t.co/Ng1jz6saNM',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/Ng1jz6saNM',
#      'expanded_url': 'https://twitter.com/i/web/status/1255683792427245570',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="https://studio.twitter.com" rel="nofollow">Twitter Media Studio</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 759251,
#    'id_str': '759251',
#    'name': 'CNN',
#    'screen_name': 'CNN',
#    'location': '',
#    'description': 'It’s our job to #GoThere & tell the most difficult stories. Join us! For more breaking news updates follow @CNNBRK  & Download our app https://t.co/UCHG9M367J',
#    'url': 'http://t.co/IaghNW8Xm2',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/IaghNW8Xm2',
#        'expanded_url': 'http://www.cnn.com',
#        'display_url': 'cnn.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': [{'url': 'https://t.co/UCHG9M367J',
#        'expanded_url': 'http://cnn.com/apps',
#        'display_url': 'cnn.com/apps',
#        'indices': [135, 158]}]}},
#    'protected': False,
#    'followers_count': 47733545,
#    'friends_count': 1106,
#    'listed_count': 145866,
#    'created_at': 'Fri Feb 09 00:35:02 +0000 2007',
#    'favourites_count': 1429,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 298104,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '323232',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/508960761826131968/LnvhR8ED_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/508960761826131968/LnvhR8ED_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/759251/1564637377',
#    'profile_link_color': '004287',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'EEEEEE',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 154,
#   'favorite_count': 486,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Apr 30 02:21:54 +0000 2020',
#   'id': 1255683769748590594,
#   'id_str': '1255683769748590594',
#   'text': 'The order to keep meat processing plants open is the height of irresponsibility and cruelty, endangering the health… https://t.co/HIpIDhknob',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/HIpIDhknob',
#      'expanded_url': 'https://twitter.com/i/web/status/1255683769748590594',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 759251,
#    'id_str': '759251',
#    'name': 'CNN',
#    'screen_name': 'CNN',
#    'location': '',
#    'description': 'It’s our job to #GoThere & tell the most difficult stories. Join us! For more breaking news updates follow @CNNBRK  & Download our app https://t.co/UCHG9M367J',
#    'url': 'http://t.co/IaghNW8Xm2',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/IaghNW8Xm2',
#        'expanded_url': 'http://www.cnn.com',
#        'display_url': 'cnn.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': [{'url': 'https://t.co/UCHG9M367J',
#        'expanded_url': 'http://cnn.com/apps',
#        'display_url': 'cnn.com/apps',
#        'indices': [135, 158]}]}},
#    'protected': False,
# ...
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 21,
#    'favorite_count': 57,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'possibly_sensitive_appealable': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 21,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Apr 30 02:20:08 +0000 2020',
#   'id': 1255683322019266560,
#   'id_str': '1255683322019266560',
#   'text': 'The US Food and Drug Administration has not yet approved any drugs for the treatment of the coronavirus. But it pla… https://t.co/GmRkNON1AC',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/GmRkNON1AC',
#      'expanded_url': 'https://twitter.com/i/web/status/1255683322019266560',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 759251,
#    'id_str': '759251',
#    'name': 'CNN',
#    'screen_name': 'CNN',
#    'location': '',
#    'description': 'It’s our job to #GoThere & tell the most difficult stories. Join us! For more breaking news updates follow @CNNBRK  & Download our app https://t.co/UCHG9M367J',
#    'url': 'http://t.co/IaghNW8Xm2',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/IaghNW8Xm2',
#        'expanded_url': 'http://www.cnn.com',
#        'display_url': 'cnn.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': [{'url': 'https://t.co/UCHG9M367J',
#        'expanded_url': 'http://cnn.com/apps',
#        'display_url': 'cnn.com/apps',
#        'indices': [135, 158]}]}},
#    'protected': False,
#    'followers_count': 47733545,
#    'friends_count': 1106,
#    'listed_count': 145866,
#    'created_at': 'Fri Feb 09 00:35:02 +0000 2007',
#    'favourites_count': 1429,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 298104,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '323232',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/508960761826131968/LnvhR8ED_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/508960761826131968/LnvhR8ED_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/759251/1564637377',
#    'profile_link_color': '004287',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'EEEEEE',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 87,
#   'favorite_count': 221,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Apr 30 02:17:13 +0000 2020',
#   'id': 1255682588405981184,
#   'id_str': '1255682588405981184',
#   'text': 'RT @OutFrontCNN: "Las Vegas, as we\'ve never seen or heard before. The entire Vegas Strip, shut down. 100% of casino doors closed. Tourists…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'OutFrontCNN',
#      'name': 'OutFrontCNN',
#      'id': 361342191,
#      'id_str': '361342191',
#      'indices': [3, 15]}],
#    'urls': []},
#   'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 759251,
#    'id_str': '759251',
#    'name': 'CNN',
#    'screen_name': 'CNN',
#    'location': '',
#    'description': 'It’s our job to #GoThere & tell the most difficult stories. Join us! For more breaking news updates follow @CNNBRK  & Download our app https://t.co/UCHG9M367J',
#    'url': 'http://t.co/IaghNW8Xm2',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/IaghNW8Xm2',
#        'expanded_url': 'http://www.cnn.com',
#        'display_url': 'cnn.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': [{'url': 'https://t.co/UCHG9M367J',
#        'expanded_url': 'http://cnn.com/apps',
#        'display_url': 'cnn.com/apps',
#        'indices': [135, 158]}]}},
#    'protected': False,
#    'followers_count': 47733545,
#    'friends_count': 1106,
#    'listed_count': 145866,
#    'created_at': 'Fri Feb 09 00:35:02 +0000 2007',
#    'favourites_count': 1429,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 298104,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '323232',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/508960761826131968/LnvhR8ED_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/508960761826131968/LnvhR8ED_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/759251/1564637377',
#    'profile_link_color': '004287',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'EEEEEE',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Thu Apr 30 00:27:47 +0000 2020',
#    'id': 1255655050459992064,
#    'id_str': '1255655050459992064',
#    'text': '"Las Vegas, as we\'ve never seen or heard before. The entire Vegas Strip, shut down. 100% of casino doors closed. To… https://t.co/T9m4fFzRPl',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/T9m4fFzRPl',
#       'expanded_url': 'https://twitter.com/i/web/status/1255655050459992064',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="https://studio.twitter.com" rel="nofollow">Twitter Media Studio</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 361342191,
#     'id_str': '361342191',
#     'name': 'OutFrontCNN',
#     'screen_name': 'OutFrontCNN',
#     'location': 'New York, NY ',
#     'description': 'Smart and entertaining, @ErinBurnett is always OutFront of the news. Erin Burnett OutFront airs weeknights at 7pm ET on @CNN and on @CNNi Saturdays & Sundays.',
#     'url': 'https://t.co/ohYB7WijK3',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/ohYB7WijK3',
#         'expanded_url': 'http://www.cnn.com/OutFront',
#         'display_url': 'cnn.com/OutFront',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 297644,
#     'friends_count': 726,
#     'listed_count': 1818,
#     'created_at': 'Wed Aug 24 16:55:20 +0000 2011',
#     'favourites_count': 166,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': True,
#     'statuses_count': 44852,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/878319130717245441/S_jpSguY_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/878319130717245441/S_jpSguY_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/361342191/1478729642',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 38,
#    'favorite_count': 68,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'possibly_sensitive_appealable': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 38,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Apr 30 02:15:00 +0000 2020',
#   'id': 1255682030802632705,
#   'id_str': '1255682030802632705',
#   'text': 'Man with 2 children allegedly pulls knife on Cambridge jogger for not social distancing https://t.co/jn9dFLL7hK #7News',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': '7News', 'indices': [112, 118]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/jn9dFLL7hK',
#      'expanded_url': 'http://whdh.com/news/man-with-2-children-allegedly-pulls-knife-on-cambridge-jogger-for-not-social-distancing/',
#      'display_url': 'whdh.com/news/man-with-…',
#      'indices': [88, 111]}]},
#   'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 16558796,
#    'id_str': '16558796',
#    'name': '7News Boston WHDH',
#    'screen_name': '7News',
#    'location': 'Boston',
#    'description': 'New England and Boston News, #BreakingNews. Have a tip? Tweet us with the hashtag #7News .\n\nFacebook: 7News - WHDH Boston\nInstagram: 7news',
#    'url': 'https://t.co/5kYmGIlLqH',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/5kYmGIlLqH',
#        'expanded_url': 'http://www.whdh.com',
#        'display_url': 'whdh.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 333209,
#    'friends_count': 1127,
#    'listed_count': 2787,
#    'created_at': 'Thu Oct 02 13:11:54 +0000 2008',
#    'favourites_count': 4454,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 284216,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/727880916354355200/-n81FrYu_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/727880916354355200/-n81FrYu_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16558796/1543525290',
#    'profile_link_color': '1B54D6',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'F0F0F0',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 2,
#   'favorite_count': 2,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Apr 30 02:14:35 +0000 2020',
#   'id': 1255681926452645888,
#   'id_str': '1255681926452645888',
#   'text': 'Elon Musk slams "fascist" social distancing measures in California, saying the orders pose a "serious risk" to the… https://t.co/xgiJFYUt2s',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/xgiJFYUt2s',
#      'expanded_url': 'https://twitter.com/i/web/status/1255681926452645888',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [116, 139]}]},
#   'source': '<a href="https://www.sprinklr.com" rel="nofollow">Sprinklr</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 15012486,
#    'id_str': '15012486',
#    'name': 'CBS News',
#    'screen_name': 'CBSNews',
#    'location': 'New York, NY',
#    'description': 'Your source for original reporting and trusted news.',
#    'url': 'https://t.co/VGut7r2Vg5',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/VGut7r2Vg5',
#        'expanded_url': 'http://CBSNews.com',
#        'display_url': 'CBSNews.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 7541383,
#    'friends_count': 515,
#    'listed_count': 52659,
#    'created_at': 'Thu Jun 05 00:54:31 +0000 2008',
#    'favourites_count': 299,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 252421,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': 'D9DADA',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/645966750941626368/d0Q4voGK_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/645966750941626368/d0Q4voGK_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15012486/1581519449',
#    'profile_link_color': 'B12124',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EAEDF0',
#    'profile_text_color': '000000',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 144,
#   'favorite_count': 613,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'en'}]

# %% [markdown]
# ### Get a certain User’s tweets

# %%
username = "@billgates"

# with the specified number of page number (x)
public_tweets = api.user_timeline(username, count=10)
#public_tweets = api.user_timeline(username, page=x)
public_tweets
# Out:
# [{'created_at': 'Wed Apr 29 03:02:38 +0000 2020',
#   'id': 1255331631486971905,
#   'id_str': '1255331631486971905',
#   'text': 'RT @gatesfoundation: Developing a vaccine against #COVID19 is among the first steps to a solution.\n\nDistributing the vaccine safely, effect…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'COVID19', 'indices': [50, 58]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'gatesfoundation',
#      'name': 'Gates Foundation',
#      'id': 17899109,
#      'id_str': '17899109',
#      'indices': [3, 19]}],
#    'urls': []},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 50393960,
#    'id_str': '50393960',
#    'name': 'Bill Gates',
#    'screen_name': 'BillGates',
#    'location': 'Seattle, WA',
#    'description': "Sharing things I'm learning through my foundation work and other interests.",
#    'url': 'https://t.co/emd1hfqSRD',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/emd1hfqSRD',
#        'expanded_url': 'https://gatesnot.es/blog',
#        'display_url': 'gatesnot.es/blog',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 50132090,
#    'friends_count': 217,
#    'listed_count': 0,
#    'created_at': 'Wed Jun 24 18:44:10 +0000 2009',
#    'favourites_count': 132,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 3305,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/988775660163252226/XpgonN0X_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/988775660163252226/XpgonN0X_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/50393960/1573055931',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Tue Apr 28 13:00:11 +0000 2020',
#    'id': 1255119620639506433,
#    'id_str': '1255119620639506433',
#    'text': 'Developing a vaccine against #COVID19 is among the first steps to a solution.\n\nDistributing the vaccine safely, eff… https://t.co/dXI9UW4s99',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'COVID19', 'indices': [29, 37]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/dXI9UW4s99',
#       'expanded_url': 'https://twitter.com/i/web/status/1255119620639506433',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="https://www.spredfast.com" rel="nofollow">Khoros Marketing</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 17899109,
#     'id_str': '17899109',
#     'name': 'Gates Foundation',
#     'screen_name': 'gatesfoundation',
#     'location': 'Seattle, Washington',
#     'description': 'Progress is possible, but only if we invest in young people’s potential.',
#     'url': 'https://t.co/VIsVwravjc',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/VIsVwravjc',
#         'expanded_url': 'http://gatesfoundation.org',
#         'display_url': 'gatesfoundation.org',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2066880,
#     'friends_count': 936,
#     'listed_count': 20908,
#     'created_at': 'Fri Dec 05 15:19:15 +0000 2008',
#     'favourites_count': 3614,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 14616,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F1EFEC',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1182061630957342720/rTA-XTJW_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1182061630957342720/rTA-XTJW_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/17899109/1570660429',
#     'profile_link_color': '9B242E',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'FFFFFF',
#     'profile_text_color': '392D1C',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 637,
#    'favorite_count': 2753,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 637,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Apr 23 16:39:33 +0000 2020',
#   'id': 1253362888678371329,
#   'id_str': '1253362888678371329',
#   'text': "We don't yet have all the tools we need to stop the novel coronavirus and safely re-open the economy. But they are… https://t.co/53Ko6OhGsd",
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/53Ko6OhGsd',
#      'expanded_url': 'https://twitter.com/i/web/status/1253362888678371329',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [116, 139]}]},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 50393960,
#    'id_str': '50393960',
#    'name': 'Bill Gates',
#    'screen_name': 'BillGates',
#    'location': 'Seattle, WA',
#    'description': "Sharing things I'm learning through my foundation work and other interests.",
#    'url': 'https://t.co/emd1hfqSRD',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/emd1hfqSRD',
#        'expanded_url': 'https://gatesnot.es/blog',
#        'display_url': 'gatesnot.es/blog',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 50132090,
#    'friends_count': 217,
#    'listed_count': 0,
#    'created_at': 'Wed Jun 24 18:44:10 +0000 2009',
#    'favourites_count': 132,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 3305,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/988775660163252226/XpgonN0X_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/988775660163252226/XpgonN0X_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/50393960/1573055931',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 4296,
#   'favorite_count': 17542,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Apr 22 15:10:17 +0000 2020',
#   'id': 1252978035692724231,
#   'id_str': '1252978035692724231',
#   'text': 'This is a great introduction to computer science concepts for students at all levels. I’m looking forward to joinin… https://t.co/BMn3caBPJn',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/BMn3caBPJn',
#      'expanded_url': 'https://twitter.com/i/web/status/1252978035692724231',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 50393960,
#    'id_str': '50393960',
#    'name': 'Bill Gates',
#    'screen_name': 'BillGates',
#    'location': 'Seattle, WA',
#    'description': "Sharing things I'm learning through my foundation work and other interests.",
#    'url': 'https://t.co/emd1hfqSRD',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/emd1hfqSRD',
#        'expanded_url': 'https://gatesnot.es/blog',
#        'display_url': 'gatesnot.es/blog',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 50132090,
#    'friends_count': 217,
#    'listed_count': 0,
#    'created_at': 'Wed Jun 24 18:44:10 +0000 2009',
#    'favourites_count': 132,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 3305,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/988775660163252226/XpgonN0X_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/988775660163252226/XpgonN0X_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/50393960/1573055931',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': True,
#   'quoted_status_id': 1251143713402662912,
#   'quoted_status_id_str': '1251143713402662912',
#   'quoted_status': {'created_at': 'Fri Apr 17 13:41:21 +0000 2020',
#    'id': 1251143713402662912,
#    'id_str': '1251143713402662912',
#    'text': 'Studying alone? Take a #CodeBreak! Join our live, interactive computer science classroom featuring @codeorg founder… https://t.co/a8ANp0vPC3',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'CodeBreak', 'indices': [23, 33]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'codeorg',
#       'name': 'Code.org',
#       'id': 850107536,
#       'id_str': '850107536',
#       'indices': [99, 107]}],
#     'urls': [{'url': 'https://t.co/a8ANp0vPC3',
#       'expanded_url': 'https://twitter.com/i/web/status/1251143713402662912',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': 1251143712052178948,
#    'in_reply_to_status_id_str': '1251143712052178948',
#    'in_reply_to_user_id': 850107536,
#    'in_reply_to_user_id_str': '850107536',
#    'in_reply_to_screen_name': 'codeorg',
#    'user': {'id': 850107536,
#     'id_str': '850107536',
#     'name': 'Code.org',
#     'screen_name': 'codeorg',
#     'location': '',
#     'description': 'https://t.co/32TV1MLhCN is a non-profit dedicated to introducing all students, especially girls and people of color, to computer science. Anybody can learn.',
#     'url': 'http://code.org',
#     'entities': {'url': {'urls': [{'url': 'http://code.org',
#         'expanded_url': None,
#         'indices': [0, 15]}]},
#      'description': {'urls': [{'url': 'https://t.co/32TV1MLhCN',
#         'expanded_url': 'http://Code.org',
#         'display_url': 'Code.org',
#         'indices': [0, 23]}]}},
#     'protected': False,
#     'followers_count': 1047526,
#     'friends_count': 817,
#     'listed_count': 4597,
#     'created_at': 'Thu Sep 27 23:10:20 +0000 2012',
#     'favourites_count': 19028,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': True,
#     'statuses_count': 9450,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '3CAFBE',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme10/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme10/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1063120830454886400/7JhtceE5_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1063120830454886400/7JhtceE5_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/850107536/1547249211',
#     'profile_link_color': '3CAFBE',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': '7AC3EE',
#     'profile_text_color': '3D1957',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 231,
#    'favorite_count': 880,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'retweet_count': 1528,
#   'favorite_count': 10240,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Apr 15 05:17:26 +0000 2020',
#   'id': 1250292126643941376,
#   'id_str': '1250292126643941376',
#   'text': 'Halting funding for the World Health Organization during a world health crisis is as dangerous as it sounds. Their… https://t.co/T8diWsSPJg',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/T8diWsSPJg',
#      'expanded_url': 'https://twitter.com/i/web/status/1250292126643941376',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [116, 139]}]},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 50393960,
#    'id_str': '50393960',
#    'name': 'Bill Gates',
#    'screen_name': 'BillGates',
#    'location': 'Seattle, WA',
#    'description': "Sharing things I'm learning through my foundation work and other interests.",
#    'url': 'https://t.co/emd1hfqSRD',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/emd1hfqSRD',
#        'expanded_url': 'https://gatesnot.es/blog',
#        'display_url': 'gatesnot.es/blog',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 50132090,
#    'friends_count': 217,
#    'listed_count': 0,
#    'created_at': 'Wed Jun 24 18:44:10 +0000 2009',
#    'favourites_count': 132,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 3305,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/988775660163252226/XpgonN0X_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/988775660163252226/XpgonN0X_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/50393960/1573055931',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 97947,
#   'favorite_count': 383309,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Mon Apr 13 00:41:08 +0000 2020',
#   'id': 1249497817900433408,
#   'id_str': '1249497817900433408',
#   'text': '.@NickKristof does an amazing job capturing the heroism of the health care workers on the front lines of the corona… https://t.co/ybw8gOlYSR',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'NickKristof',
#      'name': 'Nicholas Kristof',
#      'id': 17004618,
#      'id_str': '17004618',
#      'indices': [1, 13]}],
#    'urls': [{'url': 'https://t.co/ybw8gOlYSR',
#      'expanded_url': 'https://twitter.com/i/web/status/1249497817900433408',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 50393960,
#    'id_str': '50393960',
#    'name': 'Bill Gates',
#    'screen_name': 'BillGates',
#    'location': 'Seattle, WA',
#    'description': "Sharing things I'm learning through my foundation work and other interests.",
#    'url': 'https://t.co/emd1hfqSRD',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/emd1hfqSRD',
#        'expanded_url': 'https://gatesnot.es/blog',
#        'display_url': 'gatesnot.es/blog',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 50132090,
#    'friends_count': 217,
#    'listed_count': 0,
#    'created_at': 'Wed Jun 24 18:44:10 +0000 2009',
#    'favourites_count': 132,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 3305,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/988775660163252226/XpgonN0X_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/988775660163252226/XpgonN0X_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/50393960/1573055931',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': True,
#   'quoted_status_id': 1248996159491919873,
#   'quoted_status_id_str': '1248996159491919873',
#   'quoted_status': {'created_at': 'Sat Apr 11 15:27:44 +0000 2020',
#    'id': 1248996159491919873,
#    'id_str': '1248996159491919873',
#    'text': 'I spent 2 days in the "hot zone" in New York hospitals, witnessing needless death and heartache, and heroic, shatte… https://t.co/WHLNRAG9vH',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/WHLNRAG9vH',
#       'expanded_url': 'https://twitter.com/i/web/status/1248996159491919873',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 17004618,
#     'id_str': '17004618',
#     'name': 'Nicholas Kristof',
#     'screen_name': 'NickKristof',
#     'location': 'Everywhere',
#     'description': 'Oregon farmboy turned NY Times columnist, author with my wife, @WuDunn, of "Tightrope" https://t.co/NR8ScP6Bgr',
#     'url': 'https://t.co/CO7uxBqpWU',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/CO7uxBqpWU',
#         'expanded_url': 'http://www.nytimes.com/kristof',
#         'display_url': 'nytimes.com/kristof',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/NR8ScP6Bgr',
#         'expanded_url': 'https://bit.ly/2qUsgvr',
#         'display_url': 'bit.ly/2qUsgvr',
#         'indices': [87, 110]}]}},
#     'protected': False,
#     'followers_count': 2056099,
#     'friends_count': 2376,
#     'listed_count': 23338,
#     'created_at': 'Mon Oct 27 19:14:53 +0000 2008',
#     'favourites_count': 58,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 44016,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '9AE4E8',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/680936862387589120/DfkrlW27_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/680936862387589120/DfkrlW27_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/17004618/1578340725',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'BDDCAD',
#     'profile_sidebar_fill_color': 'DDFFCC',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 4207,
#    'favorite_count': 8951,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'retweet_count': 1465,
#   'favorite_count': 9165,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Tue Apr 07 20:59:04 +0000 2020',
#   'id': 1247629990675374081,
#   'id_str': '1247629990675374081',
#   'text': 'On #WorldHealthDay — and every day — I want to thank all of the health heroes for their sacrifices and for keeping… https://t.co/CifQrIQiJX',
#   'truncated': True,
#   'entities': {'hashtags': [{'text': 'WorldHealthDay', 'indices': [3, 18]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/CifQrIQiJX',
#      'expanded_url': 'https://twitter.com/i/web/status/1247629990675374081',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [116, 139]}]},
#   'source': '<a href="https://studio.twitter.com" rel="nofollow">Twitter Media Studio</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 50393960,
#    'id_str': '50393960',
#    'name': 'Bill Gates',
#    'screen_name': 'BillGates',
#    'location': 'Seattle, WA',
#    'description': "Sharing things I'm learning through my foundation work and other interests.",
#    'url': 'https://t.co/emd1hfqSRD',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/emd1hfqSRD',
#        'expanded_url': 'https://gatesnot.es/blog',
#        'display_url': 'gatesnot.es/blog',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 50132090,
#    'friends_count': 217,
#    'listed_count': 0,
#    'created_at': 'Wed Jun 24 18:44:10 +0000 2009',
#    'favourites_count': 132,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 3305,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/988775660163252226/XpgonN0X_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/988775660163252226/XpgonN0X_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/50393960/1573055931',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 5114,
#   'favorite_count': 31093,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sun Apr 05 22:11:06 +0000 2020',
#   'id': 1246923341769986051,
#   'id_str': '1246923341769986051',
#   'text': 'I always enjoy chatting with @Trevornoah, even though we had to sit a little bit further apart than usual this time. https://t.co/aqwtN1tS2p',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'Trevornoah',
#      'name': 'Trevor Noah',
#      'id': 46335511,
#      'id_str': '46335511',
#      'indices': [29, 40]}],
#    'urls': [{'url': 'https://t.co/aqwtN1tS2p',
#      'expanded_url': 'https://twitter.com/TheDailyShow/status/1246876853283033088',
#      'display_url': 'twitter.com/TheDailyShow/s…',
#      'indices': [117, 140]}]},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 50393960,
#    'id_str': '50393960',
#    'name': 'Bill Gates',
#    'screen_name': 'BillGates',
#    'location': 'Seattle, WA',
#    'description': "Sharing things I'm learning through my foundation work and other interests.",
#    'url': 'https://t.co/emd1hfqSRD',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/emd1hfqSRD',
#        'expanded_url': 'https://gatesnot.es/blog',
#        'display_url': 'gatesnot.es/blog',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 50132090,
#    'friends_count': 217,
#    'listed_count': 0,
#    'created_at': 'Wed Jun 24 18:44:10 +0000 2009',
#    'favourites_count': 132,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 3305,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/988775660163252226/XpgonN0X_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/988775660163252226/XpgonN0X_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/50393960/1573055931',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': True,
#   'quoted_status_id': 1246876853283033088,
#   'quoted_status_id_str': '1246876853283033088',
#   'quoted_status': {'created_at': 'Sun Apr 05 19:06:22 +0000 2020',
#    'id': 1246876853283033088,
#    'id_str': '1246876853283033088',
#    'text': 'Full interview with @BillGates: https://t.co/PPoxNqXwVM',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'BillGates',
#       'name': 'Bill Gates',
#       'id': 50393960,
#       'id_str': '50393960',
#       'indices': [20, 30]}],
#     'urls': [{'url': 'https://t.co/PPoxNqXwVM',
#       'expanded_url': 'https://youtu.be/iyFT8qXcOrM',
#       'display_url': 'youtu.be/iyFT8qXcOrM',
#       'indices': [32, 55]}]},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1246875502721134594,
#    'in_reply_to_status_id_str': '1246875502721134594',
#    'in_reply_to_user_id': 158414847,
#    'in_reply_to_user_id_str': '158414847',
#    'in_reply_to_screen_name': 'TheDailyShow',
#    'user': {'id': 158414847,
#     'id_str': '158414847',
#     'name': 'The Daily Show',
#     'screen_name': 'TheDailyShow',
#     'location': '',
#     'description': "Trevor Noah and The World's Fakest News Team. Weeknights 11/10c on @ComedyCentral.\n\nDonate to #FirstRespondersFirst: https://t.co/Nkrp4kH7Ds",
#     'url': 'https://t.co/BAakBFaEGx',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/BAakBFaEGx',
#         'expanded_url': 'http://thedailyshow.com',
#         'display_url': 'thedailyshow.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/Nkrp4kH7Ds',
#         'expanded_url': 'http://dailyshow.com/firstrespondersfirst',
#         'display_url': 'dailyshow.com/firstresponder…',
#         'indices': [117, 140]}]}},
#     'protected': False,
#     'followers_count': 8609491,
#     'friends_count': 610,
#     'listed_count': 37288,
#     'created_at': 'Tue Jun 22 16:41:05 +0000 2010',
#     'favourites_count': 1720,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 22322,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1246210124252958721/9sPxtCEL_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1246210124252958721/9sPxtCEL_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/158414847/1585954622',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 733,
#    'favorite_count': 1776,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'retweet_count': 1795,
#   'favorite_count': 18451,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Fri Apr 03 20:36:07 +0000 2020',
#   'id': 1246174663778025473,
#   'id_str': '1246174663778025473',
#   'text': 'It’s encouraging to see the first projects begin from our effort to accelerate safe and effective drugs for… https://t.co/aRhrD5klk8',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/aRhrD5klk8',
#      'expanded_url': 'https://twitter.com/i/web/status/1246174663778025473',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [109, 132]}]},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 50393960,
#    'id_str': '50393960',
#    'name': 'Bill Gates',
#    'screen_name': 'BillGates',
#    'location': 'Seattle, WA',
#    'description': "Sharing things I'm learning through my foundation work and other interests.",
#    'url': 'https://t.co/emd1hfqSRD',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/emd1hfqSRD',
#        'expanded_url': 'https://gatesnot.es/blog',
#        'display_url': 'gatesnot.es/blog',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 50132090,
#    'friends_count': 217,
#    'listed_count': 0,
#    'created_at': 'Wed Jun 24 18:44:10 +0000 2009',
#    'favourites_count': 132,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 3305,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/988775660163252226/XpgonN0X_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/988775660163252226/XpgonN0X_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/50393960/1573055931',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': True,
#   'quoted_status_id': 1246095455726886913,
#   'quoted_status_id_str': '1246095455726886913',
#   'quoted_status': {'created_at': 'Fri Apr 03 15:21:22 +0000 2020',
#    'id': 1246095455726886913,
#    'id_str': '1246095455726886913',
#    'text': 'We’re hopeful these first three grants through the COVID-19 Therapeutics Accelerator will advance our understanding… https://t.co/WxAaVgBAUX',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/WxAaVgBAUX',
#       'expanded_url': 'https://twitter.com/i/web/status/1246095455726886913',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 17899109,
#     'id_str': '17899109',
#     'name': 'Gates Foundation',
#     'screen_name': 'gatesfoundation',
#     'location': 'Seattle, Washington',
#     'description': 'Progress is possible, but only if we invest in young people’s potential.',
#     'url': 'https://t.co/VIsVwravjc',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/VIsVwravjc',
#         'expanded_url': 'http://gatesfoundation.org',
#         'display_url': 'gatesfoundation.org',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2066880,
#     'friends_count': 936,
#     'listed_count': 20908,
#     'created_at': 'Fri Dec 05 15:19:15 +0000 2008',
#     'favourites_count': 3614,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 14616,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F1EFEC',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1182061630957342720/rTA-XTJW_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1182061630957342720/rTA-XTJW_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/17899109/1570660429',
#     'profile_link_color': '9B242E',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'FFFFFF',
#     'profile_text_color': '392D1C',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 567,
#    'favorite_count': 1673,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'retweet_count': 2020,
#   'favorite_count': 12288,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Fri Apr 03 17:05:38 +0000 2020',
#   'id': 1246121692914540545,
#   'id_str': '1246121692914540545',
#   'text': 'I’m excited to join the @khanacademy Daily Homeroom today to talk about the incredible ways parents, teachers, and… https://t.co/IC4o5kMSFU',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'khanacademy',
#      'name': 'Khan Academy',
#      'id': 16689804,
#      'id_str': '16689804',
#      'indices': [24, 36]}],
#    'urls': [{'url': 'https://t.co/IC4o5kMSFU',
#      'expanded_url': 'https://twitter.com/i/web/status/1246121692914540545',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [116, 139]}]},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 50393960,
#    'id_str': '50393960',
#    'name': 'Bill Gates',
#    'screen_name': 'BillGates',
#    'location': 'Seattle, WA',
#    'description': "Sharing things I'm learning through my foundation work and other interests.",
#    'url': 'https://t.co/emd1hfqSRD',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/emd1hfqSRD',
#        'expanded_url': 'https://gatesnot.es/blog',
#        'display_url': 'gatesnot.es/blog',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 50132090,
#    'friends_count': 217,
#    'listed_count': 0,
#    'created_at': 'Wed Jun 24 18:44:10 +0000 2009',
#    'favourites_count': 132,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 3305,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/988775660163252226/XpgonN0X_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/988775660163252226/XpgonN0X_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/50393960/1573055931',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': True,
#   'quoted_status_id': 1245108716657152003,
#   'quoted_status_id_str': '1245108716657152003',
#   'quoted_status': {'created_at': 'Tue Mar 31 22:00:25 +0000 2020',
#    'id': 1245108716657152003,
#    'id_str': '1245108716657152003',
#    'text': '🎉BIG NEWS!🎉 @billgates - yes, Bill Gates - is joining Sal on our Daily Homeroom live stream this Friday at noon PT… https://t.co/eBkCxakrVX',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'BillGates',
#       'name': 'Bill Gates',
#       'id': 50393960,
#       'id_str': '50393960',
#       'indices': [12, 22]}],
#     'urls': [{'url': 'https://t.co/eBkCxakrVX',
#       'expanded_url': 'https://twitter.com/i/web/status/1245108716657152003',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'source': '<a href="http://www.falcon.io" rel="nofollow">Falcon Social Media Management </a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 16689804,
#     'id_str': '16689804',
#     'name': 'Khan Academy',
#     'screen_name': 'khanacademy',
#     'location': 'Mountain View, CA',
#     'description': 'Working to make a free, world-class education available for anyone, anywhere. https://t.co/32zoouVlXZ',
#     'url': 'https://t.co/32zoouVlXZ',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/32zoouVlXZ',
#         'expanded_url': 'http://khanacademy.org',
#         'display_url': 'khanacademy.org',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/32zoouVlXZ',
#         'expanded_url': 'http://khanacademy.org',
#         'display_url': 'khanacademy.org',
#         'indices': [78, 101]}]}},
#     'protected': False,
#     'followers_count': 700429,
#     'friends_count': 557,
#     'listed_count': 9617,
#     'created_at': 'Fri Oct 10 22:11:55 +0000 2008',
#     'favourites_count': 14149,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 5018,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1021871312195612673/MlailSlw_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1021871312195612673/MlailSlw_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16689804/1582914882',
#     'profile_link_color': '71B307',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'regular'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 183,
#    'favorite_count': 746,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'retweet_count': 951,
#   'favorite_count': 7058,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Apr 02 15:42:09 +0000 2020',
#   'id': 1245738296027697153,
#   'id_str': '1245738296027697153',
#   'text': 'If we make the right decisions now—informed by science, data and the experience of medical professionals—we can sav… https://t.co/uX2XIGcbTy',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/uX2XIGcbTy',
#      'expanded_url': 'https://twitter.com/i/web/status/1245738296027697153',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': 1245738295008489473,
#   'in_reply_to_status_id_str': '1245738295008489473',
#   'in_reply_to_user_id': 50393960,
#   'in_reply_to_user_id_str': '50393960',
#   'in_reply_to_screen_name': 'BillGates',
#   'user': {'id': 50393960,
#    'id_str': '50393960',
#    'name': 'Bill Gates',
#    'screen_name': 'BillGates',
#    'location': 'Seattle, WA',
#    'description': "Sharing things I'm learning through my foundation work and other interests.",
#    'url': 'https://t.co/emd1hfqSRD',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/emd1hfqSRD',
#        'expanded_url': 'https://gatesnot.es/blog',
#        'display_url': 'gatesnot.es/blog',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 50132090,
#    'friends_count': 217,
#    'listed_count': 0,
#    'created_at': 'Wed Jun 24 18:44:10 +0000 2009',
#    'favourites_count': 132,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 3305,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/988775660163252226/XpgonN0X_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/988775660163252226/XpgonN0X_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/50393960/1573055931',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 1576,
#   'favorite_count': 5680,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'}]

# %% [markdown]
# ### Get a User's info

# %%
try:
    target_user = username
    user_account = api.get_user(target_user)

    # Get the specific column data
    user_real_name  = user_account["name"]
    user_tweets_num = user_account["statuses_count"]
    user_followers  = user_account["followers_count"]
    user_friends    = user_account["friends_count"]
    user_favorites  = user_account["favourites_count"]
    user_Language   = user_account["lang"]    # ”en”

except tweepy.TweepError as e:
    print(f"exception for {row['Screen Name']}: {e}")

# %%
print(f'{user_real_name} has {user_tweets_num} tweets, {user_followers} followers, and {user_friends} friends.')
# Out:
# Bill Gates has 3305 tweets, 50128319 followers, and 217 friends.

# %% [markdown]
# ## Ready Functions

# %%
### FUNCTION: Get Twitter User Info ###
import datetime

def get_user_info(user_account):

    # Check user_name format
    if (user_account[0] != '@'):
        return NULL
        
    # Get user info from the Json object
    try:
        obj_user = api.get_user(user_account)
        # Get the specific column data
        user_id                = obj_user["id_str"]
        user_name              = obj_user["name"]
        user_screen_name       = obj_user["screen_name"]
        user_verified          = obj_user["verified"]
        user_created_at        = obj_user["created_at"]
        user_location          = obj_user["location"]
        user_followers_count   = obj_user["followers_count"]
        user_friends_count     = obj_user["friends_count"]
        user_listed_count      = obj_user["listed_count"]
        user_favourites_count  = obj_user["favourites_count"]
        user_statuses_count    = obj_user["statuses_count"]
        user_description       = obj_user["description"]

    except tweepy.TweepError as e:
        print(f"exception for {user_account}: {e}")

    # Date/Time Transformation
    converted_time   = datetime.datetime.strptime(user_created_at, "%a %b %d %H:%M:%S %z %Y")
    user_create_time = converted_time.strftime("%Y-%m-%d %H:%M:%S")
        
    # Return the user info needed
    user_info = {
        "user_id"                : user_id,
        "user_account"           : user_account,
        "user_name"              : user_name,
        "user_screen_name"       : user_screen_name,
        "user_verified"          : user_verified,
        "user_created_at"        : user_create_time,
        "user_location"          : user_location,
        "user_followers_count"   : user_followers_count,
        "user_friends_count"     : user_friends_count,
        "user_listed_count"      : user_listed_count,
        "user_favourites_count"  : user_favourites_count,
        "user_statuses_count"    : user_statuses_count,
        "user_description"       : user_description
    }
    return user_info

# %%
user_info = get_user_info(username)
user_info
# Out:
# {'user_id': '50393960',
#  'user_account': '@billgates',
#  'user_name': 'Bill Gates',
#  'user_screen_name': 'BillGates',
#  'user_verified': True,
#  'user_created_at': '2009-06-24 18:44:10',
#  'user_location': 'Seattle, WA',
#  'user_followers_count': 50128424,
#  'user_friends_count': 217,
#  'user_listed_count': 1,
#  'user_favourites_count': 132,
#  'user_statuses_count': 3305,
#  'user_description': "Sharing things I'm learning through my foundation work and other interests."}

# %%
### FUNCTION: Get Twitter User Info ###
import pandas as pd

def get_user_tweets(user_account, count_tweets=200):
    
    # Check user_name format
    if ((user_account[0] != '@') or not(count_tweets >= 1 and count_tweets <= 1000)):
        return NULL
    
    # Get the tweets by the user
    user_tweets = api.user_timeline(user_account, count=count_tweets)
    #print(len(user_tweets))
    
    # Prepare for the dataframe
    tweets_id             = []
    tweets_user_id        = []
    tweets_user_account   = []
    tweets_created_at     = []
    tweets_longitude      = []
    tweets_latitude       = []
    tweets_quote_count    = []
    tweets_reply_count    = []
    tweets_retweet_count  = []
    tweets_favorite_count = []
    tweets_lang           = []
    tweets_text           = []
    
    # For each tweet
    for tweet in user_tweets:
        # Get the tweet's info from the Json object
        tweet_id                        = tweet["id_str"]
        tweet_user_id                   = tweet["user"]["id_str"]
        tweet_user_acount               = user_account
        tweet_created_at                = tweet["created_at"]
        #tweet_quote_count               = tweet["quote_count"]
        tweet_quote_count               = ""
        #tweet_reply_count               = tweet["reply_count"]
        tweet_reply_count               = ""
        tweet_retweet_count             = tweet["retweet_count"]
        tweet_favorite_count            = tweet["favorite_count"]
        tweet_lang                      = tweet["lang"]
        tweet_text                      = tweet["text"]

        #print(json.dumps(tweet["coordinates"], indent=4, sort_keys=True))
        if tweet["coordinates"]:
            tweet_longitude = tweet["coordinates"]["coordinates"][0]
            tweet_latitude  = tweet["coordinates"]["coordinates"][1]
        else:
            tweet_longitude = ""
            tweet_latitude  = ""
        
        # Date/Time Transformation
        converted_time = datetime.datetime.strptime(tweet_created_at, "%a %b %d %H:%M:%S %z %Y")
        tweet_time     = converted_time.strftime("%Y-%m-%d %H:%M:%S")

        # Add the info of the tweet into the dataframe
        tweets_id.append(tweet_id)
        tweets_user_id.append(tweet_user_id)
        tweets_user_account.append(tweet_user_acount)
        tweets_created_at.append(tweet_time)
        tweets_longitude.append(tweet_longitude)
        tweets_latitude.append(tweet_latitude)
        tweets_quote_count.append(tweet_quote_count)
        tweets_reply_count.append(tweet_reply_count)
        tweets_retweet_count.append(tweet_retweet_count)
        tweets_favorite_count.append(tweet_favorite_count)
        tweets_lang.append(tweet_lang)
        tweets_text.append(tweet_text)

    # Return: tweets info
    df_tweets_info = pd.DataFrame({
        "twitter_account"    : tweets_user_account,
        "tweet_id"           : tweets_id,
        "user_id"            : tweets_user_id,
        "created_at"         : tweets_created_at,
        "quote_count"        : tweets_quote_count,
        "reply_count"        : tweets_reply_count,
        "retweet_count"      : tweets_retweet_count,
        "favorite_count"     : tweets_favorite_count,
        "lang"               : tweets_lang,
        "longitude"          : tweets_longitude,
        "latitude"           : tweets_latitude,
        "text"               : tweets_text
    })
    return df_tweets_info

# %%
df_tweets_info = user1_tweets = get_user_tweets(username, 10)
df_tweets_info
# Out:
#   twitter_account             tweet_id   user_id           created_at  \
# 0      @billgates  1255331631486971905  50393960  2020-04-29 03:02:38
# 1      @billgates  1253362888678371329  50393960  2020-04-23 16:39:33
# 2      @billgates  1252978035692724231  50393960  2020-04-22 15:10:17
# 3      @billgates  1250292126643941376  50393960  2020-04-15 05:17:26
# 4      @billgates  1249497817900433408  50393960  2020-04-13 00:41:08
# 5      @billgates  1247629990675374081  50393960  2020-04-07 20:59:04
# 6      @billgates  1246923341769986051  50393960  2020-04-05 22:11:06
# 7      @billgates  1246174663778025473  50393960  2020-04-03 20:36:07
# 8      @billgates  1246121692914540545  50393960  2020-04-03 17:05:38
# 9      @billgates  1245738296027697153  50393960  2020-04-02 15:42:09
#
#   quote_count reply_count  retweet_count  favorite_count lang longitude  \
# 0                                    637               0   en
# 1                                   4299           17543   en
# 2                                   1528           10242   en
# 3                                  97949          383290   en
# 4                                   1465            9165   en
# 5                                   5114           31092   en
# 6                                   1796           18451   en
# 7                                   2020           12288   en
# 8                                    951            7058   en
# 9                                   1576            5680   en
#
#   latitude                                               text
# 0           RT @gatesfoundation: Developing a vaccine agai...
# 1           We don't yet have all the tools we need to sto...
# 2           This is a great introduction to computer scien...
# 3           Halting funding for the World Health Organizat...
# 4           .@NickKristof does an amazing job capturing th...
# 5           On #WorldHealthDay — and every day — I want to...
# 6           I always enjoy chatting with @Trevornoah, even...
# 7           It’s encouraging to see the first projects beg...
# 8           I’m excited to join the @khanacademy Daily Hom...
# 9           If we make the right decisions now—informed by...

# %% [markdown]
# # Web Scraping

# %%
from bs4 import BeautifulSoup as bs

# %%
html_string = """
<html>
<head>
<title>
A Simple HTML Document
</title>
</head>
<body>
<p>This is a very simple HTML document</p>
<p>It only has two paragraphs</p>
</body>
</html>
"""

# %%
# Parse the HTML string
soup = bs(html_string, 'html.parser')
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
# Print formatted version of the soup
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    A Simple HTML Document
#   </title>
#  </head>
#  <body>
#   <p>
#    This is a very simple HTML document
#   </p>
#   <p>
#    It only has two paragraphs
#   </p>
#  </body>
# </html>

# %%
# Extract the title of the HTML document
soup.title
# Out:
# <title>
# A Simple HTML Document
# </title>

# %%
# Extract the contents of the HTML body
soup.body
# Out:
# <body>
# <p>This is a very simple HTML document</p>
# <p>It only has two paragraphs</p>
# </body>

# %%
# Text of the first paragraph
soup.body.p.text
# Out:
# 'This is a very simple HTML document'

# %%
# Extract all paragraph elements
soup.body.find_all('p')
# Out:
# [<p>This is a very simple HTML document</p>, <p>It only has two paragraphs</p>]

# %%
# Extract paragraph by index
soup.body.find_all('p')[0]
# Out:
# <p>This is a very simple HTML document</p>

# %% [markdown]
# ## Craigslist web scraping

# %%
# URL of page to be scraped
url = 'https://newjersey.craigslist.org/search/sss?sort=rel&query=guitar'
# Retrieve page with the requests module
response = requests.get(url)

# %%
# Create BeautifulSoup object; parse with 'html.parser'
soup = bs(response.text, 'html.parser')
# Examine the results, then determine element that contains sought info
print(soup.prettify())
# Out:
# ﻿
# <!DOCTYPE html>
# <html class="no-js">
#  <head>
#   <title>
#    north jersey for sale "guitar" - craigslist
#   </title>
#   <meta content='north jersey for sale "guitar" - craigslist' name="description"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible">
#    <link href="https://newjersey.craigslist.org/search/sss" rel="canonical"/>
#    <link href="https://newjersey.craigslist.org/search/sss?format=rss&amp;query=guitar&amp;sort=rel" rel="alternate" title='RSS feed for craigslist | north jersey for sale "guitar" - craigslist' type="application/rss+xml"/>
#    <link href="https://newjersey.craigslist.org/search/sss?s=120&amp;query=guitar&amp;sort=rel" rel="next"/>
#    <meta content="width=device-width,initial-scale=1" name="viewport"/>
#    <link href="//www.craigslist.org/styles/cl.css?v=784f71fcd82733e2b32e8d3284beaf58" media="all" rel="stylesheet" type="text/css"/>
#    <link href="//www.craigslist.org/styles/search.css?v=bc035cbbc3978b0ec9df93944cdf349b" media="all" rel="stylesheet" type="text/css"/>
#    <link href="//www.craigslist.org/styles/jquery-ui-clcustom.css?v=3b05ddffb7c7f5b62066deff2dda9339" media="all" rel="stylesheet" type="text/css"/>
#    <link href="//www.craigslist.org/styles/leaflet.css?v=d604b055c4c11b9fd29d0c071b394312" media="all" rel="stylesheet" type="text/css"/>
#    <link href="//www.craigslist.org/styles/MarkerCluster.css?v=9bea97021e746649c6837e95dd9723e8" media="all" rel="stylesheet" type="text/css"/>
#    <link href="//www.craigslist.org/styles/tocsmaps.css?v=d8743547c59d5ad31d4d7294c7e2f7f2" media="all" rel="stylesheet" type="text/css"/>
#    <!--[if IE]>
#     <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/tocsmaps-ie.css?v=6bcbe5817e70c9a7f673ff72ba3e56e5">
# <![endif]-->
#    <script type="text/javascript">
#     <!--
# var areaCountry = "US";
# var areaID = "170";
# var areaRegion = "NJ";
# var catAbb = "sss";
# var countOfTotalText = "image {count} of {total}";
# var currencySymbol = "&#x0024;";
# var defaultView = "grid";
# var expiredFavIDs = null;
# var imageConfig = {"1":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"0":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450"]},"2":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]}};
# var lessInfoText = "less info";
# var maptileBaseUrl = "//map{s}.craigslist.org/t09/{z}/{x}/{y}.png";
# var maxResults = 3000;
# var noImageText = "no image";
# var pID = null;
# var postalLat = null;
# var postalLon = null;
# var purveyorCategories = {"owner":"sso","dealer":"ssq","all":"sss"};
# var searchDistance = null;
# var sectionAbb = "sss";
# var sectionBase = "sss";
# var showInfoText = "show info";
# var showMapTabs = 1;
# var showingBanished = 0;
# var showingFavorites = 0;
# var starHint = "save this post in your favorites list";
# var subarea = null;
# var zoomToPosting = null;
# -->
#    </script>
#   </meta>
#  </head>
#  <body class="search has-map">
#   <script type="text/javascript">
#    <!--
#     function C(k){return(document.cookie.match('(^|; )'+k+'=([^;]*)')||0)[2]}
#     var pagetype, pagemode;
#     (function(){
#         var h = document.documentElement;
#         h.className = h.className.replace('no-js', 'js');
#         var b = document.body;
#         var bodyClassList = b.className.split(/\s+/);;
#         pagetype = bodyClassList[0]; // dangerous assumption
#         var fmt = C('cl_fmt');
#         if ( fmt === 'regular' || fmt === 'mobile' ) {
#             pagemode = fmt;
#         } else if (screen.width <= 480) {
#             pagemode = 'mobile';
#         } else {
#             pagemode = 'regular';
#         }
#         pagemode = pagemode === 'mobile' ? 'mobile' : 'desktop';
#         bodyClassList.push(pagemode);
#         if (C('hidesearch') === '1' && pagemode !== 'mobile') {
#             bodyClassList.push('hide-search');
#         }
#         var width = window.innerWidth || document.documentElement.clientWidth;
#         if (width > 1000) { bodyClassList.push('w1024'); }
#         if (typeof window.sectionBase !== 'undefined') {
#             var mode = (decodeURIComponent(C('cl_tocmode') || '').match(new RegExp(window.sectionBase + ':([^,]+)', 'i')) || {})[1] || window.defaultView;
#             if (mode) {
#                 bodyClassList.push(mode);
#             }
#         }
#         b.className = bodyClassList.join(' ');
#     }());
# -->
#   </script>
#   <section class="page-container" id="page-top">
#    <div class="bglogo">
#    </div>
#    <div class="tryapp">
#     try the craigslist app »
#     <a class="appstorebtn" href="https://play.google.com/store/apps/details?id=org.craigslist.CraigslistMobile">
#      Android
#     </a>
#     <a class="appstorebtn" href="https://apps.apple.com/us/app/craigslist/id1336642410">
#      iOS
#     </a>
#    </div>
#    <header class="global-header wide">
#     <a class="header-logo" href="/" name="logoLink">
#      CL
#     </a>
#     <nav class="breadcrumbs-container">
#      <form action="/search/sss" class="breadcrumbs-form" data-action="/search/###/sss" id="breadcrumbform" method="get">
#       <input name="sort" type="hidden" value="rel"/>
#       <input name="query" type="hidden" value="guitar"/>
#       <ul class="breadcrumbs ">
#        <li class="crumb area">
#         <span class="no-js">
#          <a href="/">
#           north jersey
#          </a>
#         </span>
#         <select class="js-only" id="areaAbb" name="areaAbb">
#          <option value="newjersey">
#           north jersey
#          </option>
#          <option value="albany">
#           albany, NY
#          </option>
#          <option value="allentown">
#           allentown
#          </option>
#          <option value="altoona">
#           altoona
#          </option>
#          <option value="annapolis">
#           annapolis
#          </option>
#          <option value="baltimore">
#           baltimore
#          </option>
#          <option value="binghamton">
#           binghamton
#          </option>
#          <option value="boston">
#           boston
#          </option>
#          <option value="capecod">
#           cape cod
#          </option>
#          <option value="catskills">
#           catskills
#          </option>
#          <option value="cnj">
#           central NJ
#          </option>
#          <option value="chambersburg">
#           cumberland val
#          </option>
#          <option value="delaware">
#           delaware
#          </option>
#          <option value="newlondon">
#           eastern CT
#          </option>
#          <option value="easternshore">
#           eastern shore
#          </option>
#          <option value="martinsburg">
#           eastern WV
#          </option>
#          <option value="elmira">
#           elmira
#          </option>
#          <option value="fingerlakes">
#           finger lakes
#          </option>
#          <option value="frederick">
#           frederick
#          </option>
#          <option value="glensfalls">
#           glens falls
#          </option>
#          <option value="harrisburg">
#           harrisburg
#          </option>
#          <option value="hartford">
#           hartford
#          </option>
#          <option value="hudsonvalley">
#           hudson valley
#          </option>
#          <option value="ithaca">
#           ithaca
#          </option>
#          <option value="jerseyshore">
#           jersey shore
#          </option>
#          <option value="lancaster">
#           lancaster, PA
#          </option>
#          <option value="longisland">
#           long island
#          </option>
#          <option value="nh">
#           new hampshire
#          </option>
#          <option value="newhaven">
#           new haven
#          </option>
#          <option value="newyork">
#           new york
#          </option>
#          <option value="nwct">
#           northwest CT
#          </option>
#          <option value="oneonta">
#           oneonta
#          </option>
#          <option value="philadelphia">
#           philadelphia
#          </option>
#          <option value="poconos">
#           poconos
#          </option>
#          <option value="reading">
#           reading
#          </option>
#          <option value="providence">
#           rhode island
#          </option>
#          <option value="scranton">
#           scranton
#          </option>
#          <option value="southcoast">
#           south coast
#          </option>
#          <option value="southjersey">
#           south jersey
#          </option>
#          <option value="smd">
#           southern MD
#          </option>
#          <option value="pennstate">
#           state college
#          </option>
#          <option value="syracuse">
#           syracuse
#          </option>
#          <option value="utica">
#           utica
#          </option>
#          <option value="washingtondc">
#           washington, DC
#          </option>
#          <option value="watertown">
#           watertown
#          </option>
#          <option value="westernmass">
#           western mass
#          </option>
#          <option value="williamsport">
#           williamsport
#          </option>
#          <option value="worcester">
#           worcester
#          </option>
#          <option value="york">
#           york, PA
#          </option>
#         </select>
#         <span class="breadcrumb-arrow">
#          &gt;
#         </span>
#        </li>
#        <li class="crumb section">
#         <select id="catAbb" name="catAbb">
#          <option value="ccc">
#           community
#          </option>
#          <option value="eee">
#           events
#          </option>
#          <option selected="" value="sss">
#           for sale
#          </option>
#          <option value="ggg">
#           gigs
#          </option>
#          <option value="hhh">
#           housing
#          </option>
#          <option value="jjj">
#           jobs
#          </option>
#          <option value="rrr">
#           resumes
#          </option>
#          <option value="bbb">
#           services
#          </option>
#         </select>
#         <span class="breadcrumb-arrow">
#          &gt;
#         </span>
#        </li>
#        <li class="crumb category">
#         <select class="js-only" id="subcatAbb">
#          <option value="sss">
#           all
#          </option>
#          <option value="ata">
#           antiques
#          </option>
#          <option value="ppa">
#           appliances
#          </option>
#          <option value="ara">
#           arts+crafts
#          </option>
#          <option value="sna">
#           atvs/utvs/snow
#          </option>
#          <option value="pta">
#           auto parts
#          </option>
#          <option value="wta">
#           auto wheels &amp; tires
#          </option>
#          <option value="ava">
#           aviation
#          </option>
#          <option value="baa">
#           baby+kids
#          </option>
#          <option value="bar">
#           barter
#          </option>
#          <option value="haa">
#           beauty+hlth
#          </option>
#          <option value="bip">
#           bike parts
#          </option>
#          <option value="bia">
#           bikes
#          </option>
#          <option value="bpa">
#           boat parts
#          </option>
#          <option value="boo">
#           boats
#          </option>
#          <option value="bka">
#           books
#          </option>
#          <option value="bfa">
#           business
#          </option>
#          <option value="cta">
#           cars+trucks
#          </option>
#          <option value="ema">
#           cds/dvd/vhs
#          </option>
#          <option value="moa">
#           cell phones
#          </option>
#          <option value="cla">
#           clothes+acc
#          </option>
#          <option value="cba">
#           collectibles
#          </option>
#          <option value="syp">
#           computer parts
#          </option>
#          <option value="sya">
#           computers
#          </option>
#          <option value="ela">
#           electronics
#          </option>
#          <option value="gra">
#           farm+garden
#          </option>
#          <option value="zip">
#           free stuff
#          </option>
#          <option value="fua">
#           furniture
#          </option>
#          <option value="gms">
#           garage sales
#          </option>
#          <option value="foa">
#           general
#          </option>
#          <option value="hva">
#           heavy equipment
#          </option>
#          <option value="hsa">
#           household
#          </option>
#          <option value="jwa">
#           jewelry
#          </option>
#          <option value="maa">
#           materials
#          </option>
#          <option value="mpa">
#           motorcycle parts
#          </option>
#          <option value="mca">
#           motorcycles
#          </option>
#          <option value="msa">
#           music instr
#          </option>
#          <option value="pha">
#           photo+video
#          </option>
#          <option value="rva">
#           RVs
#          </option>
#          <option value="sga">
#           sporting
#          </option>
#          <option value="tia">
#           tickets
#          </option>
#          <option value="tla">
#           tools
#          </option>
#          <option value="taa">
#           toys+games
#          </option>
#          <option value="tra">
#           trailers
#          </option>
#          <option value="vga">
#           video gaming
#          </option>
#          <option value="waa">
#           wanted
#          </option>
#         </select>
#         <span class="no-js">
#          for sale
#         </span>
#         <span class="breadcrumb-arrow">
#          &gt;
#         </span>
#        </li>
#        <li class="crumb no-js">
#         <input type="submit" value="go"/>
#        </li>
#       </ul>
#      </form>
#     </nav>
#     <div class="userlinks">
#      <ul class="user-actions">
#       <li class="user post">
#        <a href="https://post.craigslist.org/c/njy">
#         post
#        </a>
#       </li>
#       <li class="user account">
#        <a href="https://accounts.craigslist.org/login/home">
#         account
#        </a>
#       </li>
#      </ul>
#      <ul class="user-favs-discards">
#       <li class="user">
#        <div class="favorites">
#         <a class="favlink" href="#">
#          <span aria-hidden="true" class="icon icon-star fav">
#          </span>
#          <span class="fav-number">
#           0
#          </span>
#          <span class="fav-label">
#           favorites
#          </span>
#         </a>
#        </div>
#       </li>
#       <li class="user discards">
#        <form action="/favorites" class="unfavform js-only" method="POST">
#         <div class="to-banish-page">
#          <input class="lastLink" name="lastLink" type="hidden" value="//newjersey.craigslist.org/search/sss?query=guitar&amp;sort=rel"/>
#          <input class="lastTitle" name="lastTitle" type="hidden" value=""/>
#          <input class="unfaves" name="fl" type="hidden"/>
#          <input name="uf" type="hidden" value="1"/>
#          <a class="to-banish-page-link" href="#">
#           <span aria-hidden="true" class="icon icon-trash red">
#           </span>
#           <span class="banished_count">
#            0
#           </span>
#           <span class="discards-label">
#            hidden
#           </span>
#          </a>
#         </div>
#        </form>
#       </li>
#      </ul>
#     </div>
#    </header>
#    <header class="global-header narrow">
#     <a class="header-logo" href="/">
#      CL
#     </a>
#     <nav class="breadcrumbs-container">
#      <ul class="breadcrumbs">
#       north jersey            &gt;
#
# for sale
#      </ul>
#     </nav>
#     <span class="linklike show-wide-header">
#      ...
#     </span>
#    </header>
#    <form action="/search/sss" class="search-form" id="searchform">
#     <div class="querybox">
#      <div class="form-tab js-only">
#       <span class="search-open" title="hide search">
#        «
#       </span>
#       <span class="search-closed" title="show search">
#        »
#       </span>
#      </div>
#      <input autocapitalize="off" autocomplete="off" autocorrect="off" class="flatinput ui-autocomplete-input" data-autocomplete="search" id="query" name="query" placeholder="search for sale" type="text" value="guitar"/>
#      <button class="searchbtn" type="submit">
#       <span aria-hidden="true" class="icon icon-search">
#       </span>
#       <span class="screen-reader-text">
#        press to search craigslist
#       </span>
#      </button>
#      <div class="savealert">
#       <a class="saveme" data-action="save" href="https://accounts.craigslist.org/login?rt=L&amp;rp=%2Fsavesearch%2Fsave%3FURL%3Dhttps%253A%252F%252Fnewjersey%252Ecraigslist%252Eorg%252Fsearch%252Fsss%253Fquery%253Dguitar%2526sort%253Drel" title="save this search">
#        save search
#       </a>
#      </div>
#     </div>
#     <div class="search-options-container">
#      <h2 class="search-options-header linklike">
#       <div aria-hidden="true" class="icon icon-toggle-gear">
#       </div>
#       options
#       <span class="options-close">
#        close
#       </span>
#      </h2>
#      <input id="excats" name="excats" type="hidden"/>
#      <input name="sort" type="hidden" value="rel"/>
#      <div class="search-options">
#       <div class="searchgroup categories">
#        <div class="cattitle">
#         <a class="reset" href="/search/sss" title="clear all search parameters">
#          for sale
#         </a>
#        </div>
#        <ul class="maincats">
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="msa" id="cat_msa" name="cat_id" type="checkbox" value="98,184"/>
#          <a class="category" href="/search/msa?query=guitar&amp;sort=rel">
#           musical instruments
#          </a>
#          <span class="count">
#           281
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="waa" id="cat_waa" name="cat_id" type="checkbox" value="20,190"/>
#          <a class="category" href="/search/waa?query=guitar&amp;sort=rel">
#           wanted
#          </a>
#          <span class="count">
#           13
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="ela" id="cat_ela" name="cat_id" type="checkbox" value="96,167"/>
#          <a class="category" href="/search/ela?query=guitar&amp;sort=rel">
#           electronics
#          </a>
#          <span class="count">
#           11
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="vga" id="cat_vga" name="cat_id" type="checkbox" value="151,189"/>
#          <a class="category" href="/search/vga?query=guitar&amp;sort=rel">
#           video gaming
#          </a>
#          <span class="count">
#           11
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="foa" id="cat_foa" name="cat_id" type="checkbox" value="5,179"/>
#          <a class="category" href="/search/foa?query=guitar&amp;sort=rel">
#           general for sale
#          </a>
#          <span class="count">
#           8
#          </span>
#         </li>
#         <li class="morecats js-only closed">
#          <span class="linklike closed">
#           <span class="plusminus">
#            +
#           </span>
#           show 40 more
#          </span>
#          <span class="linklike open">
#           <span class="plusminus">
#            –
#           </span>
#           hide 40 more
#          </span>
#          <span class="count">
#           37
#          </span>
#         </li>
#        </ul>
#        <ul class="othercats closed">
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="bka" id="cat_bka" name="cat_id" type="checkbox" value="92,173"/>
#          <a class="category" href="/search/bka?query=guitar&amp;sort=rel">
#           books &amp; magazines
#          </a>
#          <span class="count">
#           7
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="bar" id="cat_bar" name="cat_id" type="checkbox" value="42"/>
#          <a class="category" href="/search/bar?query=guitar&amp;sort=rel">
#           barter
#          </a>
#          <span class="count">
#           6
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="taa" id="cat_taa" name="cat_id" type="checkbox" value="132,188"/>
#          <a class="category" href="/search/taa?query=guitar&amp;sort=rel">
#           toys &amp; games
#          </a>
#          <span class="count">
#           5
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="ema" id="cat_ema" name="cat_id" type="checkbox" value="117,175"/>
#          <a class="category" href="/search/ema?query=guitar&amp;sort=rel">
#           cds / dvds / vhs
#          </a>
#          <span class="count">
#           4
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="bfa" id="cat_bfa" name="cat_id" type="checkbox" value="134,174"/>
#          <a class="category" href="/search/bfa?query=guitar&amp;sort=rel">
#           business
#          </a>
#          <span class="count">
#           2
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="cba" id="cat_cba" name="cat_id" type="checkbox" value="95,177"/>
#          <a class="category" href="/search/cba?query=guitar&amp;sort=rel">
#           collectibles
#          </a>
#          <span class="count">
#           2
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="baa" id="cat_baa" name="cat_id" type="checkbox" value="107,171"/>
#          <a class="category" href="/search/baa?query=guitar&amp;sort=rel">
#           baby &amp; kid stuff
#          </a>
#          <span class="count">
#           1
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="bia" id="cat_bia" name="cat_id" type="checkbox" value="68,172"/>
#          <a class="category" href="/search/bia?query=guitar&amp;sort=rel">
#           bicycles
#          </a>
#          <span class="count">
#           1
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="moa" id="cat_moa" name="cat_id" type="checkbox" value="153,165"/>
#          <a class="category" href="/search/moa?query=guitar&amp;sort=rel">
#           cell phones
#          </a>
#          <span class="count">
#           1
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="cla" id="cat_cla" name="cat_id" type="checkbox" value="94,176"/>
#          <a class="category" href="/search/cla?query=guitar&amp;sort=rel">
#           clothing &amp; accessories
#          </a>
#          <span class="count">
#           1
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="sya" id="cat_sya" name="cat_id" type="checkbox" value="7,166"/>
#          <a class="category" href="/search/sya?query=guitar&amp;sort=rel">
#           computers
#          </a>
#          <span class="count">
#           1
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="gms" id="cat_gms" name="cat_id" type="checkbox" value="73"/>
#          <a class="category" href="/search/gms?query=guitar&amp;sort=rel">
#           garage &amp; moving sales
#          </a>
#          <span class="count">
#           1
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="haa" id="cat_haa" name="cat_id" type="checkbox" value="152,180"/>
#          <a class="category" href="/search/haa?query=guitar&amp;sort=rel">
#           health and beauty
#          </a>
#          <span class="count">
#           1
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="jwa" id="cat_jwa" name="cat_id" type="checkbox" value="120,182"/>
#          <a class="category" href="/search/jwa?query=guitar&amp;sort=rel">
#           jewelry
#          </a>
#          <span class="count">
#           1
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="maa" id="cat_maa" name="cat_id" type="checkbox" value="136,183"/>
#          <a class="category" href="/search/maa?query=guitar&amp;sort=rel">
#           materials
#          </a>
#          <span class="count">
#           1
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="sga" id="cat_sga" name="cat_id" type="checkbox" value="93,186"/>
#          <a class="category" href="/search/sga?query=guitar&amp;sort=rel">
#           sporting goods
#          </a>
#          <span class="count">
#           1
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="tla" id="cat_tla" name="cat_id" type="checkbox" value="118,187"/>
#          <a class="category" href="/search/tla?query=guitar&amp;sort=rel">
#           tools
#          </a>
#          <span class="count">
#           1
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="ata" id="cat_ata" name="cat_id" type="checkbox" value="150,169"/>
#          <a class="category" href="/search/ata?query=guitar&amp;sort=rel">
#           antiques
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="ppa" id="cat_ppa" name="cat_id" type="checkbox" value="149,162"/>
#          <a class="category" href="/search/ppa?query=guitar&amp;sort=rel">
#           appliances
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="ara" id="cat_ara" name="cat_id" type="checkbox" value="135,170"/>
#          <a class="category" href="/search/ara?query=guitar&amp;sort=rel">
#           arts &amp; crafts
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="sna" id="cat_sna" name="cat_id" type="checkbox" value="191,192"/>
#          <a class="category" href="/search/sna?query=guitar&amp;sort=rel">
#           atvs, utvs, snowmobiles
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="pta" id="cat_pta" name="cat_id" type="checkbox" value="122,163"/>
#          <a class="category" href="/search/pta?query=guitar&amp;sort=rel">
#           auto parts
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="wta" id="cat_wta" name="cat_id" type="checkbox" value="203,204"/>
#          <a class="category" href="/search/wta?query=guitar&amp;sort=rel">
#           auto wheels &amp; tires
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="ava" id="cat_ava" name="cat_id" type="checkbox" value="208,209"/>
#          <a class="category" href="/search/ava?query=guitar&amp;sort=rel">
#           aviation
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="bip" id="cat_bip" name="cat_id" type="checkbox" value="197,198"/>
#          <a class="category" href="/search/bip?query=guitar&amp;sort=rel">
#           bicycle parts
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="bpa" id="cat_bpa" name="cat_id" type="checkbox" value="201,202"/>
#          <a class="category" href="/search/bpa?query=guitar&amp;sort=rel">
#           boat parts &amp; accessories
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="boo" id="cat_boo" name="cat_id" type="checkbox" value="119,164"/>
#          <a class="category" href="/search/boo?query=guitar&amp;sort=rel">
#           boats
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="cta" id="cat_cta" name="cat_id" type="checkbox" value="145,146"/>
#          <a class="category" href="/search/cta?query=guitar&amp;sort=rel">
#           cars &amp; trucks
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="syp" id="cat_syp" name="cat_id" type="checkbox" value="199,200"/>
#          <a class="category" href="/search/syp?query=guitar&amp;sort=rel">
#           computer parts
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="gra" id="cat_gra" name="cat_id" type="checkbox" value="133,178"/>
#          <a class="category" href="/search/gra?query=guitar&amp;sort=rel">
#           farm &amp; garden
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="zip" id="cat_zip" name="cat_id" type="checkbox" value="101"/>
#          <a class="category" href="/search/zip?query=guitar&amp;sort=rel">
#           free stuff
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="fua" id="cat_fua" name="cat_id" type="checkbox" value="141,142"/>
#          <a class="category" href="/search/fua?query=guitar&amp;sort=rel">
#           furniture
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="hva" id="cat_hva" name="cat_id" type="checkbox" value="193,194"/>
#          <a class="category" href="/search/hva?query=guitar&amp;sort=rel">
#           heavy equipment
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="hsa" id="cat_hsa" name="cat_id" type="checkbox" value="97,181"/>
#          <a class="category" href="/search/hsa?query=guitar&amp;sort=rel">
#           household items
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="mpa" id="cat_mpa" name="cat_id" type="checkbox" value="195,196"/>
#          <a class="category" href="/search/mpa?query=guitar&amp;sort=rel">
#           motorcycle parts &amp; accessories
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="mca" id="cat_mca" name="cat_id" type="checkbox" value="69,160"/>
#          <a class="category" href="/search/mca?query=guitar&amp;sort=rel">
#           motorcycles/scooters
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="pha" id="cat_pha" name="cat_id" type="checkbox" value="137,185"/>
#          <a class="category" href="/search/pha?query=guitar&amp;sort=rel">
#           photo/video
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="rva" id="cat_rva" name="cat_id" type="checkbox" value="124,168"/>
#          <a class="category" href="/search/rva?query=guitar&amp;sort=rel">
#           recreational vehicles
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="tia" id="cat_tia" name="cat_id" type="checkbox" value="44,161"/>
#          <a class="category" href="/search/tia?query=guitar&amp;sort=rel">
#           tickets
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="tra" id="cat_tra" name="cat_id" type="checkbox" value="205,206"/>
#          <a class="category" href="/search/tra?query=guitar&amp;sort=rel">
#           trailers
#          </a>
#          <span class="count">
#           0
#          </span>
#         </li>
#        </ul>
#        <div class="selectall js-only checked">
#         <label>
#          <input checked="checked" class="catcheck selectallcb" type="checkbox"/>
#          <span class="all linklike">
#           select all
#          </span>
#         </label>
#        </div>
#       </div>
#       <input name="userid" type="hidden" value="">
#        <ul class="searchgroup buttongroup purveyor">
#         <li class="button sel">
#          <a data-val="all" href="/search/sss?query=guitar&amp;sort=rel">
#           all
#          </a>
#         </li>
#         <li class="button ">
#          <a data-val="owner" href="/search/sso?query=guitar&amp;sort=rel">
#           owner
#          </a>
#         </li>
#         <li class="button ">
#          <a data-val="dealer" href="/search/ssq?query=guitar&amp;sort=rel">
#           dealer
#          </a>
#         </li>
#        </ul>
#        <div class="searchgroup">
#         <ul>
#          <li>
#           <label class="srchType">
#            <input class="" name="srchType" type="checkbox" value="T"/>
#            search titles only
#           </label>
#          </li>
#          <li>
#           <label class="hasPic">
#            <input class="autosubmit" name="hasPic" type="checkbox" value="1"/>
#            has image
#           </label>
#          </li>
#          <li>
#           <label class="postedToday">
#            <input class="autosubmit" name="postedToday" type="checkbox" value="1"/>
#            posted today
#           </label>
#          </li>
#          <li>
#           <label class="bundleDuplicates">
#            <input class="autosubmit" name="bundleDuplicates" type="checkbox" value="1"/>
#            bundle duplicates
#           </label>
#          </li>
#          <li>
#           <label class="searchNearby">
#            <input class="autosubmit" name="searchNearby" type="checkbox" value="1"/>
#            include nearby areas
#           </label>
#          </li>
#         </ul>
#         <ul class="js-only nearbyAreas ">
#          <li class="nearbyZone nearbyZone_3">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_19" name="nearbyArea" type="checkbox" value="59">
#             albany, NY
#             <small>
#              (alb)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_7">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_44" name="nearbyArea" type="checkbox" value="355">
#             altoona-johnstown
#             <small>
#              (aoo)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_6">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_36" name="nearbyArea" type="checkbox" value="460">
#             annapolis, MD
#             <small>
#              (anp)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_5">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_32" name="nearbyArea" type="checkbox" value="34">
#             baltimore, MD
#             <small>
#              (bal)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_3">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_18" name="nearbyArea" type="checkbox" value="248">
#             binghamton, NY
#             <small>
#              (bgm)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_6">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_37" name="nearbyArea" type="checkbox" value="4">
#             boston
#             <small>
#              (bos)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_9">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_56" name="nearbyArea" type="checkbox" value="40">
#             buffalo, NY
#             <small>
#              (buf)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_7">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_42" name="nearbyArea" type="checkbox" value="239">
#             cape cod / islands
#             <small>
#              (cap)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_8" name="nearbyArea" type="checkbox" value="451">
#             catskills
#             <small>
#              (cat)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_1" name="nearbyArea" type="checkbox" value="349">
#             central NJ
#             <small>
#              (cnj)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_10">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_61" name="nearbyArea" type="checkbox" value="290">
#             charlottesville, VA
#             <small>
#              (uva)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_9">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_57" name="nearbyArea" type="checkbox" value="452">
#             chautauqua, NY
#             <small>
#              (chq)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_6">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_39" name="nearbyArea" type="checkbox" value="705">
#             cumberland valley
#             <small>
#              (cbg)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_3">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_21" name="nearbyArea" type="checkbox" value="193">
#             delaware
#             <small>
#              (dlw)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_2">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_15" name="nearbyArea" type="checkbox" value="281">
#             eastern CT
#             <small>
#              (nlo)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_7">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_45" name="nearbyArea" type="checkbox" value="444">
#             eastern panhandle
#             <small>
#              (ewv)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_5">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_34" name="nearbyArea" type="checkbox" value="328">
#             eastern shore
#             <small>
#              (esh)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_4">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_27" name="nearbyArea" type="checkbox" value="453">
#             elmira-corning
#             <small>
#              (elm)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_5">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_33" name="nearbyArea" type="checkbox" value="685">
#             finger lakes, NY
#             <small>
#              (fgl)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_6">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_40" name="nearbyArea" type="checkbox" value="633">
#             frederick, MD
#             <small>
#              (fdk)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_8">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_51" name="nearbyArea" type="checkbox" value="457">
#             fredericksburg, VA
#             <small>
#              (ezf)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_5">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_30" name="nearbyArea" type="checkbox" value="686">
#             glens falls, NY
#             <small>
#              (gfl)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_3">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_22" name="nearbyArea" type="checkbox" value="166">
#             harrisburg, PA
#             <small>
#              (hrs)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_9">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_59" name="nearbyArea" type="checkbox" value="447">
#             harrisonburg, VA
#             <small>
#              (shd)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_2">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_12" name="nearbyArea" type="checkbox" value="44">
#             hartford, CT
#             <small>
#              (htf)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_3" name="nearbyArea" type="checkbox" value="249">
#             hudson valley, NY
#             <small>
#              (hud)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_4">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_28" name="nearbyArea" type="checkbox" value="201">
#             ithaca, NY
#             <small>
#              (ith)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_2" name="nearbyArea" type="checkbox" value="561">
#             jersey shore
#             <small>
#              (jys)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_3">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_20" name="nearbyArea" type="checkbox" value="279">
#             lancaster, PA
#             <small>
#              (lns)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_7" name="nearbyArea" type="checkbox" value="167">
#             lehigh valley
#             <small>
#              (alt)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_4" name="nearbyArea" type="checkbox" value="250">
#             long island, NY
#             <small>
#              (isp)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_7">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_47" name="nearbyArea" type="checkbox" value="198">
#             new hampshire
#             <small>
#              (nhm)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_6" name="nearbyArea" type="checkbox" value="168">
#             new haven, CT
#             <small>
#              (hvn)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_0" name="nearbyArea" type="checkbox" value="3">
#             new york city
#             <small>
#              (nyc)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_10">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_60" name="nearbyArea" type="checkbox" value="48">
#             norfolk / hampton roads
#             <small>
#              (nfk)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_9" name="nearbyArea" type="checkbox" value="354">
#             northwest CT
#             <small>
#              (nct)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_2">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_16" name="nearbyArea" type="checkbox" value="684">
#             oneonta, NY
#             <small>
#              (onh)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_10" name="nearbyArea" type="checkbox" value="17">
#             philadelphia
#             <small>
#              (phi)
#             </small>
#            </input>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_10">
#           <label class="nearby">
# ...
#           favorite this post
#          </span>
#         </span>
#         <time class="result-date" datetime="2020-04-10 08:47" title="Fri 10 Apr 08:47:04 AM">
#          Apr 10
#         </time>
#         <a class="result-title hdrlnk" data-id="7104700865" href="https://newjersey.craigslist.org/ele/d/wallington-xbox-360-racing-wheel-kinect/7104700865.html">
#          Xbox 360 E, Racing Wheel, Kinect sensor, Guitar, DVDs and all the cables
#         </a>
#         <span class="result-meta">
#          <span class="result-price">
#           $220
#          </span>
#          <span class="result-tags">
#           <span class="pictag">
#            pic
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            hide this posting
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            restore
#           </span>
#           <span class="restore-wide-text">
#            restore this posting
#           </span>
#          </a>
#         </span>
#        </p>
#       </li>
#       <li class="result-row" data-pid="7106149356">
#        <a class="result-image gallery" data-ids="1:00T0T_kYYUb5Dojyf,1:00H0H_8SZhWXdA3n7,1:00I0I_j6SdHkqIFvF" href="https://newjersey.craigslist.org/msg/d/bloomfield-road-runner-6-space-guitar/7106149356.html">
#         <span class="result-price">
#          $125
#         </span>
#        </a>
#        <p class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           favorite this post
#          </span>
#         </span>
#         <time class="result-date" datetime="2020-04-10 08:05" title="Fri 10 Apr 08:05:38 AM">
#          Apr 10
#         </time>
#         <a class="result-title hdrlnk" data-id="7106149356" href="https://newjersey.craigslist.org/msg/d/bloomfield-road-runner-6-space-guitar/7106149356.html">
#          Road Runner 6 Space Guitar Stand
#         </a>
#         <span class="result-meta">
#          <span class="result-price">
#           $125
#          </span>
#          <span class="result-hood">
#           (Bloomfield)
#          </span>
#          <span class="result-tags">
#           <span class="pictag">
#            pic
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            hide this posting
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            restore
#           </span>
#           <span class="restore-wide-text">
#            restore this posting
#           </span>
#          </a>
#         </span>
#        </p>
#       </li>
#       <li class="result-row" data-pid="7105873733">
#        <a class="result-image gallery" data-ids="1:00202_ijvbYwMmbmY,1:00Z0Z_6uLkaf2TM2v" href="https://newjersey.craigslist.org/msg/d/ringwood-crate-gx-15r-guitar-amp/7105873733.html">
#         <span class="result-price">
#          $70
#         </span>
#        </a>
#        <p class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           favorite this post
#          </span>
#         </span>
#         <time class="result-date" datetime="2020-04-09 15:03" title="Thu 09 Apr 03:03:52 PM">
#          Apr  9
#         </time>
#         <a class="result-title hdrlnk" data-id="7105873733" href="https://newjersey.craigslist.org/msg/d/ringwood-crate-gx-15r-guitar-amp/7105873733.html">
#          Crate gx 15r guitar amp
#         </a>
#         <span class="result-meta">
#          <span class="result-price">
#           $70
#          </span>
#          <span class="result-hood">
#           (Ringwood)
#          </span>
#          <span class="result-tags">
#           <span class="pictag">
#            pic
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            hide this posting
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            restore
#           </span>
#           <span class="restore-wide-text">
#            restore this posting
#           </span>
#          </a>
#         </span>
#        </p>
#       </li>
#       <li class="result-row" data-pid="
# https://newjersey.craigslist.org/msg/d/black-vox-electric-guitar-mint/7108032325.html
# -------------
# yamaha acoustic guitar fg 441s
# $275
# https://newjersey.craigslist.org/msg/d/wayne-yamaha-acoustic-guitar-fg-441s/7102843939.html
# -------------
# Speakers guitar and Bass
# $0
# https://newjersey.craigslist.org/msg/d/bloomfield-speakers-guitar-and-bass/7097015070.html
# -------------
# Telecaster style guitar with hard case
# $250
# https://newjersey.craigslist.org/msg/d/closter-telecaster-style-guitar-with/7107243848.html
# -------------
# SELLING GUITAR
# $125
# https://newjersey.craigslist.org/msg/d/leonia-selling-guitar/7106847475.html
# -------------
# Oscar Schmidt OG-1 Acoustic Guitar 3/4 size
# $80
# https://newjersey.craigslist.org/msg/d/basking-ridge-oscar-schmidt-og-1/7106805891.html
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# -------------
# Squier Stratocaster guitar
# $99
# https://newjersey.craigslist.org/msg/d/rutherford-squier-stratocaster-guitar/7106258333.html
# -------------
# Line 6 Spider IV 75 75W 1x12 Guitar Combo Amplifier
# $200
# https://newjersey.craigslist.org/msg/d/rutherford-line-6-spider-iv-75-75w-1x12/7106255525.html
# -------------
# Washburn WI-PRO guitar
# $300
# https://newjersey.craigslist.org/msg/d/rutherford-washburn-wi-pro-guitar/7106251051.html
# -------------
# Xbox 360 E, Racing Wheel, Kinect sensor, Guitar, DVDs and all the cables
# $220
# https://newjersey.craigslist.org/ele/d/wallington-xbox-360-racing-wheel-kinect/7104700865.html
# -------------
# Road Runner 6 Space Guitar Stand
# $125
# https://newjersey.craigslist.org/msg/d/bloomfield-road-runner-6-space-guitar/7106149356.html
# -------------
# Crate gx 15r guitar amp
# $70
# https://newjersey.craigslist.org/msg/d/ringwood-crate-gx-15r-guitar-amp/7105873733.html
# -------------
# Jackson JS32 Randy Rhodes Flying V Solid Body Guitar Black
# $225
# https://newjersey.craigslist.org/msg/d/hawthorne-jackson-js32-randy-rhodes/7105591724.html

# %% [markdown]
# ## Web Scraping with Pandas
# Pandas automatically scrapes any tabular data from a page

# %%
import pandas as pd

# %%
url = 'https://en.wikipedia.org/wiki/List_of_capitals_in_the_United_States'
tables = pd.read_html(url)
len(tables)
# Out:
# 7

# %% [markdown]
# It returns a list of dataframes for any tabular data that Pandas found

# %%
for i in range(len(tables)):
    df = tables[i]
    print(f"Table [{i}]#################################")
    print(df.head())
# Out:
# Table [0]#################################
#     0                                                  1
# 0 NaN  This section may require cleanup to meet Wikip...
# Table [1]#################################
#         0             1              2           3              4   \
# 0    State          Abr.     State-hood     Capital  Capital since
# 1     City  Metropolitan  Rank in state  Rank in US            NaN
# 2  Alabama            AL           1819  Montgomery           1846
# 3   Alaska            AK           1959      Juneau           1906
# 4  Arizona            AZ           1912     Phoenix           1889
#
#            5                  6        7    8      9   \
# 0  Area (mi²)  Population (2018)    Notes  NaN    NaN
# 1         NaN                NaN      NaN  NaN    NaN
# 2       159.8             198218   373903  2.0  119.0
# 3      2716.7              31275      NaN  3.0    NaN
# 4       517.6            1660272  4857962  1.0    5.0
#
#                                         10
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3  Largest capital by municipal land area.
# 4           Largest capital by population.
# Table [2]#################################
#                           0     1     2          3                  4  \
# 0              Insular area  Abr.  Date    Capital  Population (2010)
# 1            American Samoa    AS  1899  Pago Pago               3656
# 2                      Guam    GU  1898    Hagåtña               1051
# 3  Northern Mariana Islands    MP  1947     Saipan              48220
# 4               Puerto Rico    PR  1898   San Juan             395326
#
#                                                    5
# 0                                              Notes
# 1  Pago Pago refers to both a village and a group...
# 2              Dededo is the area's largest village.
# 3                                                NaN
# 4  The city of San Juan was originally called Pue...
# Table [3]#################################
#                               0                                            1  \
# 0                         State                                      Capital
# 1  Alabama[17]Statehood in 1819                                  San Agustín
# 2                      Savannah                                         1733
# 3                          1755  Capital of the British Province of Georgia.
# 4                          1776            Capitals of the State of Georgia.
#
#                                                    2  \
# 0                                               Date
# 1                                               1565
# 2  Capital of the British proprietary Colony of G...
# 3                                                NaN
# 4                                                NaN
#
#                                                   3
# 0                                             Notes
# 1  Capital of the Spanish colony of La Florida.[18]
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# Table [4]#################################
#                                                    0
# 0   vteCapitals of the United States by jurisdiction
# 1  Nation: US Washington States: AL Montgomery AK...
# Table [5]#################################
#                                                    0  \
# 0               vteUnited States state-related lists
# 1  List of states and territories of the United S...
# 2                                       Demographics
# 3                                            Economy
# 4                                        Environment
#
#                                                    1
# 0                                                NaN
# 1                                                NaN
# 2  Population African American Amish Asian Birth ...
# 3  Billionaires Budgets Companies Credit ratings ...
# 4  Botanical gardens Carbon dioxide emissions Par...
# Table [6]#################################
#                                                  0  \
# 0  vteLocation of the capital of the United States
# 1                               Temporary capitals
# 2                                Permanent capital
#
#                                                    1
# 0                                                NaN
# 1  Philadelphia (1776; 1777; 1778–1783; 1791–1800...
# 2                      Washington, D.C. (since 1800)

# %%
df = tables[1].iloc[2:]
df.columns = ['State', 'Abr.', 'State-hood Rank', 'Capital', 
              'Capital Since', 'Area (sq-mi)', 'Municipal Population', 'Metropolitan', 
              'Metropolitan Population', 'Population Rank', 'Notes']
df.set_index('State', inplace=True)
df.head()
# Out:
#            Abr. State-hood Rank      Capital Capital Since Area (sq-mi)  \
# State
# Alabama      AL            1819   Montgomery          1846        159.8
# Alaska       AK            1959       Juneau          1906       2716.7
# Arizona      AZ            1912      Phoenix          1889        517.6
# Arkansas     AR            1836  Little Rock          1821        116.2
# California   CA            1850   Sacramento          1854         97.9
#
#            Municipal Population Metropolitan  Metropolitan Population  \
# State
# Alabama                  198218       373903                      2.0
# Alaska                    31275          NaN                      3.0
# Arizona                 1660272      4857962                      1.0
# Arkansas                 193524       699757                      1.0
# California               508529      2345210                      6.0
#
#             Population Rank                                    Notes
# State
# Alabama               119.0                                      NaN
# Alaska                  NaN  Largest capital by municipal land area.
# Arizona                 5.0           Largest capital by population.
# Arkansas              117.0                                      NaN
# California             35.0                                      NaN

# %%
df.loc['Illinois']
# Out:
# Abr.                                IL
# State-hood Rank                   1818
# Capital                    Springfield
# Capital Since                     1837
# Area (sq-mi)                      54.0
# Municipal Population            116250
# Metropolitan                    210170
# Metropolitan Population              6
# Population Rank                    221
# Notes                              NaN
# Name: Illinois, dtype: object
